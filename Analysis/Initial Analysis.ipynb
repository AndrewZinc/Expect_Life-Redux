# %%
# Import the dependencies
import os
from dotenv import load_dotenv
from pymongo import MongoClient
import pandas as pd

# %%
# load the config from the .env file
load_dotenv()
MONGODB_URI = os.environ['MONGODB_URI']

# Connect to the database engine
client = MongoClient(MONGODB_URI)

# connect to the project db
db = client['ExpectLifeRedux']

# get a reference to the data collection
data = db['ELR_Data']

# %%
# Create a dataframe from the collection
combined_df = pd.DataFrame(list(data.find()))
combined_df.head(5)
# Out:
#                         _id  Country_Year  Country  Year  \
# 0  654d9eb5dae30abb52d2be23  Albania_1990  Albania  1990
# 1  654d9eb5dae30abb52d2be24  Albania_1991  Albania  1991
# 2  654d9eb5dae30abb52d2be25  Albania_1992  Albania  1992
# 3  654d9eb5dae30abb52d2be26  Albania_1993  Albania  1993
# 4  654d9eb5dae30abb52d2be27  Albania_1994  Albania  1994
#
#                  Gov Type  SSS Depth  \
# 0  parliamentary republic        2.0
# 1  parliamentary republic        2.0
# 2  parliamentary republic        2.0
# 3  parliamentary republic        2.0
# 4  parliamentary republic        2.0
#
#                                             SSS Type  Avg Rainfall (mm/yr)  \
# 0  Universal medical benefits,Social insurance (c...                1485.0
# 1  Universal medical benefits,Social insurance (c...                1485.0
# 2  Universal medical benefits,Social insurance (c...                1485.0
# 3  Universal medical benefits,Social insurance (c...                1485.0
# 4  Universal medical benefits,Social insurance (c...                1485.0
#
#    Pop Density (#/sq km)  Total Population (M)  ...  \
# 0             119.946788              3.286542  ...
# 1             119.225912              3.266790  ...
# 2             118.505073              3.247039  ...
# 3             117.784197              3.227287  ...
# 4             117.063358              3.207536  ...
#
#    Current HE per capita (PPP Intl $)  Capital HE (% GDP)  \
# 0                          222.786533            0.005188
# 1                          222.786533            0.005188
# 2                          222.786533            0.005188
# 3                          222.786533            0.005188
# 4                          222.786533            0.005188
#
#    Domestic General Gov HE (% GDP)  \
# 0                         2.765835
# 1                         2.765835
# 2                         2.765835
# 3                         2.765835
# 4                         2.765835
#
#    Domestic General Gov HE per capita (PPP Intl $)  \
# 0                                       103.662764
# 1                                       103.662764
# 2                                       103.662764
# 3                                       103.662764
# 4                                       103.662764
#
#    Domestic Private HE per capita (PPP Intl $)  GDP growth per capita %  \
# 0                                   115.435286               -11.187905
# 1                                   115.435286               -27.566821
# 2                                   115.435286                -6.622551
# 3                                   115.435286                10.229949
# 4                                   115.435286                 8.969762
#
#    GDP per capita (PPP Intl $)  Daily Caloric Supply  Tobacco use (% adults)  \
# 0                  2549.746801                2568.0                    35.0
# 1                  1909.319160                2572.0                    35.0
# 2                  1823.503609                2654.0                    35.0
# 3                  2057.692048                2795.0                    35.0
# 4                  2290.143917                2877.0                    35.0
#
#    Alcohol Use per capita (liters)
# 0                             6.57
# 1                             6.57
# 2                             6.57
# 3                             6.57
# 4                             6.57
#
# [5 rows x 25 columns]

# %%
# Drop the database id data and refresh the index
combined_df = combined_df.drop(['_id'], axis=1)
combined_df = combined_df.reset_index(drop=True)
combined_df.head(5)
# Out:
#    Country_Year  Country  Year                Gov Type  SSS Depth  \
# 0  Albania_1990  Albania  1990  parliamentary republic        2.0
# 1  Albania_1991  Albania  1991  parliamentary republic        2.0
# 2  Albania_1992  Albania  1992  parliamentary republic        2.0
# 3  Albania_1993  Albania  1993  parliamentary republic        2.0
# 4  Albania_1994  Albania  1994  parliamentary republic        2.0
#
#                                             SSS Type  Avg Rainfall (mm/yr)  \
# 0  Universal medical benefits,Social insurance (c...                1485.0
# 1  Universal medical benefits,Social insurance (c...                1485.0
# 2  Universal medical benefits,Social insurance (c...                1485.0
# 3  Universal medical benefits,Social insurance (c...                1485.0
# 4  Universal medical benefits,Social insurance (c...                1485.0
#
#    Pop Density (#/sq km)  Total Population (M)  Total Labor Force (M)  ...  \
# 0             119.946788              3.286542               1.374478  ...
# 1             119.225912              3.266790               1.429833  ...
# 2             118.505073              3.247039               1.438342  ...
# 3             117.784197              3.227287               1.413557  ...
# 4             117.063358              3.207536               1.391914  ...
#
#    Current HE per capita (PPP Intl $)  Capital HE (% GDP)  \
# 0                          222.786533            0.005188
# 1                          222.786533            0.005188
# 2                          222.786533            0.005188
# 3                          222.786533            0.005188
# 4                          222.786533            0.005188
#
#    Domestic General Gov HE (% GDP)  \
# 0                         2.765835
# 1                         2.765835
# 2                         2.765835
# 3                         2.765835
# 4                         2.765835
#
#    Domestic General Gov HE per capita (PPP Intl $)  \
# 0                                       103.662764
# 1                                       103.662764
# 2                                       103.662764
# 3                                       103.662764
# 4                                       103.662764
#
#    Domestic Private HE per capita (PPP Intl $)  GDP growth per capita %  \
# 0                                   115.435286               -11.187905
# 1                                   115.435286               -27.566821
# 2                                   115.435286                -6.622551
# 3                                   115.435286                10.229949
# 4                                   115.435286                 8.969762
#
#    GDP per capita (PPP Intl $)  Daily Caloric Supply  Tobacco use (% adults)  \
# 0                  2549.746801                2568.0                    35.0
# 1                  1909.319160                2572.0                    35.0
# 2                  1823.503609                2654.0                    35.0
# 3                  2057.692048                2795.0                    35.0
# 4                  2290.143917                2877.0                    35.0
#
#    Alcohol Use per capita (liters)
# 0                             6.57
# 1                             6.57
# 2                             6.57
# 3                             6.57
# 4                             6.57
#
# [5 rows x 24 columns]
