# %%
# Import the dependencies
import os
from dotenv import load_dotenv
import pymongo as pym
from pymongo import MongoClient
import pymongoarrow as pma
from pymongoarrow.api import write
import pandas as pd

import re
from sklearn.cluster import HDBSCAN
from sklearn.preprocessing import MaxAbsScaler
from sklearn.decomposition import PCA
import sweetviz as sv

# %%
# load the config from the .env file
load_dotenv()
MONGODB_URI = os.environ['MONGODB_URI']

# Connect to the database engine
client = MongoClient(MONGODB_URI)

# connect to the project db
db = client['ExpectLifeRedux']

# get a reference to the data collection
data = db['ELR_Data']

# %%
# Create a dataframe from the collection
combined_df = pd.DataFrame(list(data.find()))
combined_df.head(5)
# Out:
#                         _id  Country_Year  Country  Year  \
# 0  656c8a4891b27078d5aba381  Albania_1990  Albania  1990
# 1  656c8a4891b27078d5aba382  Albania_1991  Albania  1991
# 2  656c8a4891b27078d5aba383  Albania_1992  Albania  1992
# 3  656c8a4891b27078d5aba384  Albania_1993  Albania  1993
# 4  656c8a4891b27078d5aba385  Albania_1994  Albania  1994
#
#                  Gov Type  SSS Depth  \
# 0  parliamentary republic          2
# 1  parliamentary republic          2
# 2  parliamentary republic          2
# 3  parliamentary republic          2
# 4  parliamentary republic          2
#
#                                             SSS Type  Avg Rainfall (mm/yr)  \
# 0  Universal medical benefits,Social insurance sy...                1485.0
# 1  Universal medical benefits,Social insurance sy...                1485.0
# 2  Universal medical benefits,Social insurance sy...                1485.0
# 3  Universal medical benefits,Social insurance sy...                1485.0
# 4  Universal medical benefits,Social insurance sy...                1485.0
#
#    Pop Density (#/sq km)  Total Population (M)  ...  \
# 0             119.946788              3.286542  ...
# 1             119.225912              3.266790  ...
# 2             118.505073              3.247039  ...
# 3             117.784197              3.227287  ...
# 4             117.063358              3.207536  ...
#
#    Current HE per capita (PPP Intl $)  Capital HE (% GDP)  \
# 0                          222.786533            0.005188
# 1                          222.786533            0.005188
# 2                          222.786533            0.005188
# 3                          222.786533            0.005188
# 4                          222.786533            0.005188
#
#    Domestic General Gov HE (% GDP)  \
# 0                         2.765835
# 1                         2.765835
# 2                         2.765835
# 3                         2.765835
# 4                         2.765835
#
#    Domestic General Gov HE per capita (PPP Intl $)  \
# 0                                       103.662764
# 1                                       103.662764
# 2                                       103.662764
# 3                                       103.662764
# 4                                       103.662764
#
#    Domestic Private HE per capita (PPP Intl $)  GDP growth per capita %  \
# 0                                   115.435286               -11.187905
# 1                                   115.435286               -27.566821
# 2                                   115.435286                -6.622551
# 3                                   115.435286                10.229949
# 4                                   115.435286                 8.969762
#
#    GDP per capita (PPP Intl $)  Daily Caloric Supply  Tobacco use (% adults)  \
# 0                  2549.746801                2568.0                    35.0
# 1                  1909.319160                2572.0                    35.0
# 2                  1823.503609                2654.0                    35.0
# 3                  2057.692048                2795.0                    35.0
# 4                  2290.143917                2877.0                    35.0
#
#    Alcohol Use per capita (liters)
# 0                             6.57
# 1                             6.57
# 2                             6.57
# 3                             6.57
# 4                             6.57
#
# [5 rows x 25 columns]

# %%
# Drop the database id data and refresh the index
combined_df = combined_df.drop(['_id'], axis=1)
combined_df = combined_df.reset_index(drop=True)

# Create a new DataFrame for the country_years.  Apply the country_years as the new index for later merging.
country_year_df = pd.DataFrame()
country_year_df['Country_Year'] = combined_df['Country_Year']
country_year_df['Country'] = combined_df['Country']
country_year_df['Year'] = combined_df['Year']
country_year_df = country_year_df.set_index('Country_Year', drop=False)

# Set the DataFrame index to the country names to get them out of the way
combined_df= combined_df.set_index('Country_Year')
ori_df = combined_df.copy()
combined_df.head(5)
# Out:
#               Country  Year                Gov Type  SSS Depth  \
# Country_Year
# Albania_1990  Albania  1990  parliamentary republic          2
# Albania_1991  Albania  1991  parliamentary republic          2
# Albania_1992  Albania  1992  parliamentary republic          2
# Albania_1993  Albania  1993  parliamentary republic          2
# Albania_1994  Albania  1994  parliamentary republic          2
#
#                                                        SSS Type  \
# Country_Year
# Albania_1990  Universal medical benefits,Social insurance sy...
# Albania_1991  Universal medical benefits,Social insurance sy...
# Albania_1992  Universal medical benefits,Social insurance sy...
# Albania_1993  Universal medical benefits,Social insurance sy...
# Albania_1994  Universal medical benefits,Social insurance sy...
#
#               Avg Rainfall (mm/yr)  Pop Density (#/sq km)  \
# Country_Year
# Albania_1990                1485.0             119.946788
# Albania_1991                1485.0             119.225912
# Albania_1992                1485.0             118.505073
# Albania_1993                1485.0             117.784197
# Albania_1994                1485.0             117.063358
#
#               Total Population (M)  Total Labor Force (M)  LEx years  ...  \
# Country_Year                                                          ...
# Albania_1990              3.286542               1.374478     73.144  ...
# Albania_1991              3.266790               1.429833     73.378  ...
# Albania_1992              3.247039               1.438342     73.715  ...
# Albania_1993              3.227287               1.413557     73.939  ...
# Albania_1994              3.207536               1.391914     74.131  ...
#
#               Current HE per capita (PPP Intl $)  Capital HE (% GDP)  \
# Country_Year
# Albania_1990                          222.786533            0.005188
# Albania_1991                          222.786533            0.005188
# Albania_1992                          222.786533            0.005188
# Albania_1993                          222.786533            0.005188
# Albania_1994                          222.786533            0.005188
#
#               Domestic General Gov HE (% GDP)  \
# Country_Year
# Albania_1990                         2.765835
# Albania_1991                         2.765835
# Albania_1992                         2.765835
# Albania_1993                         2.765835
# Albania_1994                         2.765835
#
#               Domestic General Gov HE per capita (PPP Intl $)  \
# Country_Year
# Albania_1990                                       103.662764
# Albania_1991                                       103.662764
# Albania_1992                                       103.662764
# Albania_1993                                       103.662764
# Albania_1994                                       103.662764
#
#               Domestic Private HE per capita (PPP Intl $)  \
# Country_Year
# Albania_1990                                   115.435286
# Albania_1991                                   115.435286
# Albania_1992                                   115.435286
# Albania_1993                                   115.435286
# Albania_1994                                   115.435286
#
#               GDP growth per capita %  GDP per capita (PPP Intl $)  \
# Country_Year
# Albania_1990               -11.187905                  2549.746801
# Albania_1991               -27.566821                  1909.319160
# Albania_1992                -6.622551                  1823.503609
# Albania_1993                10.229949                  2057.692048
# Albania_1994                 8.969762                  2290.143917
#
#               Daily Caloric Supply  Tobacco use (% adults)  \
# Country_Year
# Albania_1990                2568.0                    35.0
# Albania_1991                2572.0                    35.0
# Albania_1992                2654.0                    35.0
# Albania_1993                2795.0                    35.0
# Albania_1994                2877.0                    35.0
#
#               Alcohol Use per capita (liters)
# Country_Year
# Albania_1990                             6.57
# Albania_1991                             6.57
# Albania_1992                             6.57
# Albania_1993                             6.57
# Albania_1994                             6.57
#
# [5 rows x 23 columns]

# %%
# Create a new DataFrame for the SSS data.
SSS_df = combined_df[['SSS Depth', 'SSS Type']].copy()
SSS_df
# Out:
#                SSS Depth                                           SSS Type
# Country_Year
# Albania_1990           2  Universal medical benefits,Social insurance sy...
# Albania_1991           2  Universal medical benefits,Social insurance sy...
# Albania_1992           2  Universal medical benefits,Social insurance sy...
# Albania_1993           2  Universal medical benefits,Social insurance sy...
# Albania_1994           2  Universal medical benefits,Social insurance sy...
# ...                  ...                                                ...
# Zimbabwe_2018          1  Employer-liability system (cash sickness benef...
# Zimbabwe_2019          1  Employer-liability system (cash sickness benef...
# Zimbabwe_2020          1  Employer-liability system (cash sickness benef...
# Zimbabwe_2021          1  Employer-liability system (cash sickness benef...
# Zimbabwe_2022          1  Employer-liability system (cash sickness benef...
#
# [6105 rows x 2 columns]

# %%
#create a list of SSS component phrases to match
component_terms = ["community-based social insurance","employer-liability system (cash benefits)","employer-liability system (cash maternity benefits)","employer-liability system (cash medical benefits)","employer-liability system (cash sickness benefits)","employer-liability system (maternity benefits)","employer-liability system (medical benefits)","employer-liability system (parental leave)","employer-liability system (paternity benefits)","employer-liability system (paternity leave)","employer-liability system (sickness benefits)","employer-liability system through private carriers","employer-liability system","employment-related system (cash benefits)","employment-related system (cash maternity benefits)","employment-related system (cash sickness benefits)","employment-related system (parental benefits)","employment-related system (tuberculosis benefits)","mandatory health insurance (medical benefits)","mandatory health insurance through private carriers (medical benefits)","mandatory individual account system (medical benefits)","mandatory private insurance (cash benefits)","mandatory private insurance (medical benefits)","mandatory private insurance","mandatory private pension scheme","open pension funds","provident fund (birth grant)","provident fund (medical benefits)","Retirement pension scheme","social assistance system (birth grant)","social assistance system (cash benefits)","social assistance system (cash birth grants)","social assistance system (cash maternity benefits)","social assistance system (cash sickness benefits)","social assistance system (funeral grant)","social assistance system (long-term care benefits)","social assistance system (maternity benefits)","social assistance system (medical benefits)","social assistance system (parental leave)","social assistance system","social insurance system (cash benefits)","social insurance system (cash maternity benefits)","social insurance system (cash medical benefits)","social insurance system (cash parental benefits)","social insurance system (cash sickness benefits)","social insurance system (cash sickness)","social insurance system (child care benefits)","social insurance system (in-kind benefits)","social insurance system (maternity benefits)","social insurance system (maternity medical benefits)","social insurance system (medical benefits)","social insurance system (prenatal benefits)","social insurance system","universal (adoption grant)","universal (birth grant)","universal (cash maternity benefits)","universal (cash parental grants)","universal (paid parental leave)","universal (parental benefits)","universal (pregnancy grant)","universal (prenatal care grant)","universal medical benefits","voluntary community-based social insurance system (medical benefits)","voluntary pension scheme"]

# %%
# Create a regex pattern from the list of components that will match across word boundaries
regex_pattern = r'(' + '|'.join(map(re.escape, sorted(component_terms, key=len, reverse=True))) + r')'

# Ensure the pattern is compiled for efficiency
compiled_pattern = re.compile(regex_pattern, flags=re.IGNORECASE)

# Function to match components using regex
def find_components(system_type, pattern):
    # Find all matches of the pattern within the system_type string
    matches = re.findall(pattern, system_type)
    return list(set(matches))  # return unique matches only

# Apply this function to the 'system_type' column
SSS_df['components_matched'] = SSS_df['SSS Type'].apply(lambda x: find_components(x, compiled_pattern))
SSS_df
# Out:
#                SSS Depth                                           SSS Type  \
# Country_Year
# Albania_1990           2  Universal medical benefits,Social insurance sy...
# Albania_1991           2  Universal medical benefits,Social insurance sy...
# Albania_1992           2  Universal medical benefits,Social insurance sy...
# Albania_1993           2  Universal medical benefits,Social insurance sy...
# Albania_1994           2  Universal medical benefits,Social insurance sy...
# ...                  ...                                                ...
# Zimbabwe_2018          1  Employer-liability system (cash sickness benef...
# Zimbabwe_2019          1  Employer-liability system (cash sickness benef...
# Zimbabwe_2020          1  Employer-liability system (cash sickness benef...
# Zimbabwe_2021          1  Employer-liability system (cash sickness benef...
# Zimbabwe_2022          1  Employer-liability system (cash sickness benef...
#
#                                               components_matched
# Country_Year
# Albania_1990   [Social insurance system (cash benefits), Univ...
# Albania_1991   [Social insurance system (cash benefits), Univ...
# Albania_1992   [Social insurance system (cash benefits), Univ...
# Albania_1993   [Social insurance system (cash benefits), Univ...
# Albania_1994   [Social insurance system (cash benefits), Univ...
# ...                                                          ...
# Zimbabwe_2018  [Employer-liability system (maternity benefits...
# Zimbabwe_2019  [Employer-liability system (maternity benefits...
# Zimbabwe_2020  [Employer-liability system (maternity benefits...
# Zimbabwe_2021  [Employer-liability system (maternity benefits...
# Zimbabwe_2022  [Employer-liability system (maternity benefits...
#
# [6105 rows x 3 columns]

# %%
# components_matched contains lists of matched SSS component texts
components_df = SSS_df['components_matched'].str.join('|').str.get_dummies('|')

# Concatenate with original df
encoded_df = pd.concat([SSS_df, components_df], axis=1)

# %%
encoded_df.head(2)
# Out:
#               SSS Depth                                           SSS Type  \
# Country_Year
# Albania_1990          2  Universal medical benefits,Social insurance sy...
# Albania_1991          2  Universal medical benefits,Social insurance sy...
#
#                                              components_matched  \
# Country_Year
# Albania_1990  [Social insurance system (cash benefits), Univ...
# Albania_1991  [Social insurance system (cash benefits), Univ...
#
#               Community-based social insurance  Employer-liability system  \
# Country_Year
# Albania_1990                                 0                          0
# Albania_1991                                 0                          0
#
#               Employer-liability system (cash benefits)  \
# Country_Year
# Albania_1990                                          0
# Albania_1991                                          0
#
#               Employer-liability system (cash maternity benefits)  \
# Country_Year
# Albania_1990                                                  0
# Albania_1991                                                  0
#
#               Employer-liability system (cash medical benefits)  \
# Country_Year
# Albania_1990                                                  0
# Albania_1991                                                  0
#
#               Employer-liability system (cash sickness benefits)  \
# Country_Year
# Albania_1990                                                  0
# Albania_1991                                                  0
#
#               Employer-liability system (maternity benefits)  ...  \
# Country_Year                                                  ...
# Albania_1990                                               0  ...
# Albania_1991                                               0  ...
#
#               Universal (birth grant)  Universal (cash maternity benefits)  \
# Country_Year
# Albania_1990                        0                                    0
# Albania_1991                        0                                    0
#
#               Universal (cash parental grants)  \
# Country_Year
# Albania_1990                                 0
# Albania_1991                                 0
#
#               Universal (paid parental leave)  Universal (parental benefits)  \
# Country_Year
# Albania_1990                                0                              0
# Albania_1991                                0                              0
#
#               Universal (pregnancy grant)  Universal (prenatal care grant)  \
# Country_Year
# Albania_1990                            0                                0
# Albania_1991                            0                                0
#
#               Universal medical benefits  \
# Country_Year
# Albania_1990                           1
# Albania_1991                           1
#
#               Voluntary community-based social insurance system (medical benefits)  \
# Country_Year
# Albania_1990                                                  0
# Albania_1991                                                  0
#
#               Voluntary pension scheme
# Country_Year
# Albania_1990                         0
# Albania_1991                         0
#
# [2 rows x 67 columns]

# %%
# Drop the text columns
encoded_df = encoded_df.drop(['SSS Type','components_matched'], axis=1)
encoded_df.head(2)
# Out:
#               SSS Depth  Community-based social insurance  \
# Country_Year
# Albania_1990          2                                 0
# Albania_1991          2                                 0
#
#               Employer-liability system  \
# Country_Year
# Albania_1990                          0
# Albania_1991                          0
#
#               Employer-liability system (cash benefits)  \
# Country_Year
# Albania_1990                                          0
# Albania_1991                                          0
#
#               Employer-liability system (cash maternity benefits)  \
# Country_Year
# Albania_1990                                                  0
# Albania_1991                                                  0
#
#               Employer-liability system (cash medical benefits)  \
# Country_Year
# Albania_1990                                                  0
# Albania_1991                                                  0
#
#               Employer-liability system (cash sickness benefits)  \
# Country_Year
# Albania_1990                                                  0
# Albania_1991                                                  0
#
#               Employer-liability system (maternity benefits)  \
# Country_Year
# Albania_1990                                               0
# Albania_1991                                               0
#
#               Employer-liability system (medical benefits)  \
# Country_Year
# Albania_1990                                             0
# Albania_1991                                             0
#
#               Employer-liability system (parental leave)  ...  \
# Country_Year                                              ...
# Albania_1990                                           0  ...
# Albania_1991                                           0  ...
#
#               Universal (birth grant)  Universal (cash maternity benefits)  \
# Country_Year
# Albania_1990                        0                                    0
# Albania_1991                        0                                    0
#
#               Universal (cash parental grants)  \
# Country_Year
# Albania_1990                                 0
# Albania_1991                                 0
#
#               Universal (paid parental leave)  Universal (parental benefits)  \
# Country_Year
# Albania_1990                                0                              0
# Albania_1991                                0                              0
#
#               Universal (pregnancy grant)  Universal (prenatal care grant)  \
# Country_Year
# Albania_1990                            0                                0
# Albania_1991                            0                                0
#
#               Universal medical benefits  \
# Country_Year
# Albania_1990                           1
# Albania_1991                           1
#
#               Voluntary community-based social insurance system (medical benefits)  \
# Country_Year
# Albania_1990                                                  0
# Albania_1991                                                  0
#
#               Voluntary pension scheme
# Country_Year
# Albania_1990                         0
# Albania_1991                         0
#
# [2 rows x 65 columns]

# %%
# Collect the column labels so they can be reapplied after data scaling
encoded_col_names = encoded_df.columns.tolist()

# %%
# Standardize the data with MaxAbsScaler(). Using this scaler to maintain integrity of sparse encoded values.
scaler = MaxAbsScaler()

encode_scaled_nda = scaler.fit_transform(encoded_df)
encode_scaled_nda
# Out:
# array([[0.4, 0. , 0. , ..., 1. , 0. , 0. ],
#        [0.4, 0. , 0. , ..., 1. , 0. , 0. ],
#        [0.4, 0. , 0. , ..., 1. , 0. , 0. ],
#        ...,
#        [0.2, 0. , 0. , ..., 0. , 0. , 0. ],
#        [0.2, 0. , 0. , ..., 0. , 0. , 0. ],
#        [0.2, 0. , 0. , ..., 0. , 0. , 0. ]])

# %%
# Convert the scaled-encoded data back to a DataFrame (nda = Numpy Data Array)
sss_se_df = pd.DataFrame(encode_scaled_nda, index=encoded_df.index)

# Apply the column labels to ensure the data is properly identified
sss_se_df = sss_se_df.set_axis(encoded_col_names, axis=1)
sss_se_df
# Out:
#                SSS Depth  Community-based social insurance  \
# Country_Year
# Albania_1990         0.4                               0.0
# Albania_1991         0.4                               0.0
# Albania_1992         0.4                               0.0
# Albania_1993         0.4                               0.0
# Albania_1994         0.4                               0.0
# ...                  ...                               ...
# Zimbabwe_2018        0.2                               0.0
# Zimbabwe_2019        0.2                               0.0
# Zimbabwe_2020        0.2                               0.0
# Zimbabwe_2021        0.2                               0.0
# Zimbabwe_2022        0.2                               0.0
#
#                Employer-liability system  \
# Country_Year
# Albania_1990                         0.0
# Albania_1991                         0.0
# Albania_1992                         0.0
# Albania_1993                         0.0
# Albania_1994                         0.0
# ...                                  ...
# Zimbabwe_2018                        0.0
# Zimbabwe_2019                        0.0
# Zimbabwe_2020                        0.0
# Zimbabwe_2021                        0.0
# Zimbabwe_2022                        0.0
#
#                Employer-liability system (cash benefits)  \
# Country_Year
# Albania_1990                                         0.0
# Albania_1991                                         0.0
# Albania_1992                                         0.0
# Albania_1993                                         0.0
# Albania_1994                                         0.0
# ...                                                  ...
# Zimbabwe_2018                                        0.0
# Zimbabwe_2019                                        0.0
# Zimbabwe_2020                                        0.0
# Zimbabwe_2021                                        0.0
# Zimbabwe_2022                                        0.0
#
#                Employer-liability system (cash maternity benefits)  \
# Country_Year
# Albania_1990                                                 0.0
# Albania_1991                                                 0.0
# Albania_1992                                                 0.0
# Albania_1993                                                 0.0
# Albania_1994                                                 0.0
# ...                                                          ...
# Zimbabwe_2018                                                0.0
# Zimbabwe_2019                                                0.0
# Zimbabwe_2020                                                0.0
# Zimbabwe_2021                                                0.0
# Zimbabwe_2022                                                0.0
#
#                Employer-liability system (cash medical benefits)  \
# Country_Year
# Albania_1990                                                 0.0
# Albania_1991                                                 0.0
# Albania_1992                                                 0.0
# Albania_1993                                                 0.0
# Albania_1994                                                 0.0
# ...                                                          ...
# Zimbabwe_2018                                                0.0
# Zimbabwe_2019                                                0.0
# Zimbabwe_2020                                                0.0
# Zimbabwe_2021                                                0.0
# Zimbabwe_2022                                                0.0
#
#                Employer-liability system (cash sickness benefits)  \
# Country_Year
# Albania_1990                                                 0.0
# Albania_1991                                                 0.0
# Albania_1992                                                 0.0
# Albania_1993                                                 0.0
# Albania_1994                                                 0.0
# ...                                                          ...
# Zimbabwe_2018                                                1.0
# Zimbabwe_2019                                                1.0
# Zimbabwe_2020                                                1.0
# Zimbabwe_2021                                                1.0
# Zimbabwe_2022                                                1.0
#
#                Employer-liability system (maternity benefits)  \
# Country_Year
# Albania_1990                                              0.0
# Albania_1991                                              0.0
# Albania_1992                                              0.0
# Albania_1993                                              0.0
# Albania_1994                                              0.0
# ...                                                       ...
# Zimbabwe_2018                                             1.0
# Zimbabwe_2019                                             1.0
# Zimbabwe_2020                                             1.0
# Zimbabwe_2021                                             1.0
# Zimbabwe_2022                                             1.0
#
#                Employer-liability system (medical benefits)  \
# Country_Year
# Albania_1990                                            0.0
# Albania_1991                                            0.0
# Albania_1992                                            0.0
# Albania_1993                                            0.0
# Albania_1994                                            0.0
# ...                                                     ...
# Zimbabwe_2018                                           0.0
# Zimbabwe_2019                                           0.0
# Zimbabwe_2020                                           0.0
# Zimbabwe_2021                                           0.0
# Zimbabwe_2022                                           0.0
#
#                Employer-liability system (parental leave)  ...  \
# Country_Year                                               ...
# Albania_1990                                          0.0  ...
# Albania_1991                                          0.0  ...
# Albania_1992                                          0.0  ...
# Albania_1993                                          0.0  ...
# Albania_1994                                          0.0  ...
# ...                                                   ...  ...
# Zimbabwe_2018                                         0.0  ...
# Zimbabwe_2019                                         0.0  ...
# Zimbabwe_2020                                         0.0  ...
# Zimbabwe_2021                                         0.0  ...
# Zimbabwe_2022                                         0.0  ...
#
#                Universal (birth grant)  Universal (cash maternity benefits)  \
# Country_Year
# Albania_1990                       0.0                                  0.0
# Albania_1991                       0.0                                  0.0
# Albania_1992                       0.0                                  0.0
# Albania_1993                       0.0                                  0.0
# Albania_1994                       0.0                                  0.0
# ...                                ...                                  ...
# Zimbabwe_2018                      0.0                                  0.0
# Zimbabwe_2019                      0.0                                  0.0
# Zimbabwe_2020                      0.0                                  0.0
# Zimbabwe_2021                      0.0                                  0.0
# Zimbabwe_2022                      0.0                                  0.0
#
#                Universal (cash parental grants)  \
# Country_Year
# Albania_1990                                0.0
# Albania_1991                                0.0
# Albania_1992                                0.0
# Albania_1993                                0.0
# Albania_1994                                0.0
# ...                                         ...
# Zimbabwe_2018                               0.0
# Zimbabwe_2019                               0.0
# Zimbabwe_2020                               0.0
# Zimbabwe_2021                               0.0
# Zimbabwe_2022                               0.0
#
#                Universal (paid parental leave)  Universal (parental benefits)  \
# Country_Year
# Albania_1990                               0.0                            0.0
# Albania_1991                               0.0                            0.0
# Albania_1992                               0.0                            0.0
# Albania_1993                               0.0                            0.0
# Albania_1994                               0.0                            0.0
# ...                                        ...                            ...
# Zimbabwe_2018                              0.0                            0.0
# Zimbabwe_2019                              0.0                            0.0
# Zimbabwe_2020                              0.0                            0.0
# Zimbabwe_2021                              0.0                            0.0
# Zimbabwe_2022                              0.0                            0.0
#
#                Universal (pregnancy grant)  Universal (prenatal care grant)  \
# Country_Year
# Albania_1990                           0.0                              0.0
# Albania_1991                           0.0                              0.0
# Albania_1992                           0.0                              0.0
# Albania_1993                           0.0                              0.0
# Albania_1994                           0.0                              0.0
# ...                                    ...                              ...
# Zimbabwe_2018                          0.0                              0.0
# Zimbabwe_2019                          0.0                              0.0
# Zimbabwe_2020                          0.0                              0.0
# Zimbabwe_2021                          0.0                              0.0
# Zimbabwe_2022                          0.0                              0.0
#
#                Universal medical benefits  \
# Country_Year
# Albania_1990                          1.0
# Albania_1991                          1.0
# Albania_1992                          1.0
# Albania_1993                          1.0
# Albania_1994                          1.0
# ...                                   ...
# Zimbabwe_2018                         0.0
# Zimbabwe_2019                         0.0
# Zimbabwe_2020                         0.0
# Zimbabwe_2021                         0.0
# Zimbabwe_2022                         0.0
#
#                Voluntary community-based social insurance system (medical benefits)  \
# Country_Year
# Albania_1990                                                 0.0
# Albania_1991                                                 0.0
# Albania_1992                                                 0.0
# Albania_1993                                                 0.0
# Albania_1994                                                 0.0
# ...                                                          ...
# Zimbabwe_2018                                                0.0
# Zimbabwe_2019                                                0.0
# Zimbabwe_2020                                                0.0
# Zimbabwe_2021                                                0.0
# Zimbabwe_2022                                                0.0
#
#                Voluntary pension scheme
# Country_Year
# Albania_1990                        0.0
# Albania_1991                        0.0
# Albania_1992                        0.0
# Albania_1993                        0.0
# Albania_1994                        0.0
# ...                                 ...
# Zimbabwe_2018                       0.0
# Zimbabwe_2019                       0.0
# Zimbabwe_2020                       0.0
# Zimbabwe_2021                       0.0
# Zimbabwe_2022                       0.0
#
# [6105 rows x 65 columns]

# %%
# define the model
SSS_model = HDBSCAN(n_jobs=-1)

# Fit the model - Make predictions
SSS_pred = SSS_model.fit_predict(sss_se_df)

# Add the predicted class columns
sss_se_df['SSS Class'] = SSS_model.labels_

# %% [raw]
# # Generate a sweetviz analysis report
# SSS_report = sv.analyze(sss_se_df)
#
# SSS_report.show_html(filepath='SSS_HDBSCAN-get_dummies.html', layout='vertical')

# %%
sss_se_df
# Out:
#                SSS Depth  Community-based social insurance  \
# Country_Year
# Albania_1990         0.4                               0.0
# Albania_1991         0.4                               0.0
# Albania_1992         0.4                               0.0
# Albania_1993         0.4                               0.0
# Albania_1994         0.4                               0.0
# ...                  ...                               ...
# Zimbabwe_2018        0.2                               0.0
# Zimbabwe_2019        0.2                               0.0
# Zimbabwe_2020        0.2                               0.0
# Zimbabwe_2021        0.2                               0.0
# Zimbabwe_2022        0.2                               0.0
#
#                Employer-liability system  \
# Country_Year
# Albania_1990                         0.0
# Albania_1991                         0.0
# Albania_1992                         0.0
# Albania_1993                         0.0
# Albania_1994                         0.0
# ...                                  ...
# Zimbabwe_2018                        0.0
# Zimbabwe_2019                        0.0
# Zimbabwe_2020                        0.0
# Zimbabwe_2021                        0.0
# Zimbabwe_2022                        0.0
#
#                Employer-liability system (cash benefits)  \
# Country_Year
# Albania_1990                                         0.0
# Albania_1991                                         0.0
# Albania_1992                                         0.0
# Albania_1993                                         0.0
# Albania_1994                                         0.0
# ...                                                  ...
# Zimbabwe_2018                                        0.0
# Zimbabwe_2019                                        0.0
# Zimbabwe_2020                                        0.0
# Zimbabwe_2021                                        0.0
# Zimbabwe_2022                                        0.0
#
#                Employer-liability system (cash maternity benefits)  \
# Country_Year
# Albania_1990                                                 0.0
# Albania_1991                                                 0.0
# Albania_1992                                                 0.0
# Albania_1993                                                 0.0
# Albania_1994                                                 0.0
# ...                                                          ...
# Zimbabwe_2018                                                0.0
# Zimbabwe_2019                                                0.0
# Zimbabwe_2020                                                0.0
# Zimbabwe_2021                                                0.0
# Zimbabwe_2022                                                0.0
#
#                Employer-liability system (cash medical benefits)  \
# Country_Year
# Albania_1990                                                 0.0
# Albania_1991                                                 0.0
# Albania_1992                                                 0.0
# Albania_1993                                                 0.0
# Albania_1994                                                 0.0
# ...                                                          ...
# Zimbabwe_2018                                                0.0
# Zimbabwe_2019                                                0.0
# Zimbabwe_2020                                                0.0
# Zimbabwe_2021                                                0.0
# Zimbabwe_2022                                                0.0
#
#                Employer-liability system (cash sickness benefits)  \
# Country_Year
# Albania_1990                                                 0.0
# Albania_1991                                                 0.0
# Albania_1992                                                 0.0
# Albania_1993                                                 0.0
# Albania_1994                                                 0.0
# ...                                                          ...
# Zimbabwe_2018                                                1.0
# Zimbabwe_2019                                                1.0
# Zimbabwe_2020                                                1.0
# Zimbabwe_2021                                                1.0
# Zimbabwe_2022                                                1.0
#
#                Employer-liability system (maternity benefits)  \
# Country_Year
# Albania_1990                                              0.0
# Albania_1991                                              0.0
# Albania_1992                                              0.0
# Albania_1993                                              0.0
# Albania_1994                                              0.0
# ...                                                       ...
# Zimbabwe_2018                                             1.0
# Zimbabwe_2019                                             1.0
# Zimbabwe_2020                                             1.0
# Zimbabwe_2021                                             1.0
# Zimbabwe_2022                                             1.0
#
#                Employer-liability system (medical benefits)  \
# Country_Year
# Albania_1990                                            0.0
# Albania_1991                                            0.0
# Albania_1992                                            0.0
# Albania_1993                                            0.0
# Albania_1994                                            0.0
# ...                                                     ...
# Zimbabwe_2018                                           0.0
# Zimbabwe_2019                                           0.0
# Zimbabwe_2020                                           0.0
# Zimbabwe_2021                                           0.0
# Zimbabwe_2022                                           0.0
#
#                Employer-liability system (parental leave)  ...  \
# Country_Year                                               ...
# Albania_1990                                          0.0  ...
# Albania_1991                                          0.0  ...
# Albania_1992                                          0.0  ...
# Albania_1993                                          0.0  ...
# Albania_1994                                          0.0  ...
# ...                                                   ...  ...
# Zimbabwe_2018                                         0.0  ...
# Zimbabwe_2019                                         0.0  ...
# Zimbabwe_2020                                         0.0  ...
# Zimbabwe_2021                                         0.0  ...
# Zimbabwe_2022                                         0.0  ...
#
#                Universal (cash maternity benefits)  \
# Country_Year
# Albania_1990                                   0.0
# Albania_1991                                   0.0
# Albania_1992                                   0.0
# Albania_1993                                   0.0
# Albania_1994                                   0.0
# ...                                            ...
# Zimbabwe_2018                                  0.0
# Zimbabwe_2019                                  0.0
# Zimbabwe_2020                                  0.0
# Zimbabwe_2021                                  0.0
# Zimbabwe_2022                                  0.0
#
#                Universal (cash parental grants)  \
# Country_Year
# Albania_1990                                0.0
# Albania_1991                                0.0
# Albania_1992                                0.0
# Albania_1993                                0.0
# Albania_1994                                0.0
# ...                                         ...
# Zimbabwe_2018                               0.0
# Zimbabwe_2019                               0.0
# Zimbabwe_2020                               0.0
# Zimbabwe_2021                               0.0
# Zimbabwe_2022                               0.0
#
#                Universal (paid parental leave)  Universal (parental benefits)  \
# Country_Year
# Albania_1990                               0.0                            0.0
# Albania_1991                               0.0                            0.0
# Albania_1992                               0.0                            0.0
# Albania_1993                               0.0                            0.0
# Albania_1994                               0.0                            0.0
# ...                                        ...                            ...
# Zimbabwe_2018                              0.0                            0.0
# Zimbabwe_2019                              0.0                            0.0
# Zimbabwe_2020                              0.0                            0.0
# Zimbabwe_2021                              0.0                            0.0
# Zimbabwe_2022                              0.0                            0.0
#
#                Universal (pregnancy grant)  Universal (prenatal care grant)  \
# Country_Year
# Albania_1990                           0.0                              0.0
# Albania_1991                           0.0                              0.0
# Albania_1992                           0.0                              0.0
# Albania_1993                           0.0                              0.0
# Albania_1994                           0.0                              0.0
# ...                                    ...                              ...
# Zimbabwe_2018                          0.0                              0.0
# Zimbabwe_2019                          0.0                              0.0
# Zimbabwe_2020                          0.0                              0.0
# Zimbabwe_2021                          0.0                              0.0
# Zimbabwe_2022                          0.0                              0.0
#
#                Universal medical benefits  \
# Country_Year
# Albania_1990                          1.0
# Albania_1991                          1.0
# Albania_1992                          1.0
# Albania_1993                          1.0
# Albania_1994                          1.0
# ...                                   ...
# Zimbabwe_2018                         0.0
# Zimbabwe_2019                         0.0
# Zimbabwe_2020                         0.0
# Zimbabwe_2021                         0.0
# Zimbabwe_2022                         0.0
#
#                Voluntary community-based social insurance system (medical benefits)  \
# Country_Year
# Albania_1990                                                 0.0
# Albania_1991                                                 0.0
# Albania_1992                                                 0.0
# Albania_1993                                                 0.0
# Albania_1994                                                 0.0
# ...                                                          ...
# Zimbabwe_2018                                                0.0
# Zimbabwe_2019                                                0.0
# Zimbabwe_2020                                                0.0
# Zimbabwe_2021                                                0.0
# Zimbabwe_2022                                                0.0
#
#                Voluntary pension scheme  SSS Class
# Country_Year
# Albania_1990                        0.0         81
# Albania_1991                        0.0         81
# Albania_1992                        0.0         81
# Albania_1993                        0.0         81
# Albania_1994                        0.0         81
# ...                                 ...        ...
# Zimbabwe_2018                       0.0         77
# Zimbabwe_2019                       0.0         77
# Zimbabwe_2020                       0.0         77
# Zimbabwe_2021                       0.0         77
# Zimbabwe_2022                       0.0         77
#
# [6105 rows x 66 columns]

# %%
# Create a dictionary to send to MongoDB - Alternate method, not necessary when using PyMongoArrow
#sss_dict = sss_se_df.to_dict('records')
#sss_dict

# %%
# load the config from the .env file
load_dotenv()
MONGODB_URI = os.environ['MONGODB_URI']

# Connect to the database engine
client = MongoClient(MONGODB_URI)

# connect to the project db
db = client['ExpectLifeRedux']

# get a reference to the data collection
SSS_data = db['SSS_Clusters']

# write the data to the database (alternate method)
#SSS_data.insert_many(sss_dict)

# %%
# prefered method - use PyMongoArrow
write(db.SSS_Clusters, sss_se_df)
# Out:
# C:\Users\AZ\anaconda3\envs\gpu\lib\site-packages\pyarrow\pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# {'insertedCount': 6105}

# %%
# Add the SSS_Class to the original dataframe
combined_df['SSS Class'] = sss_se_df['SSS_class']
combined_df
