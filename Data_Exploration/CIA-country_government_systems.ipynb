# %%
# Import Splinter, BeautifulSoup, and Pandas
from splinter import Browser
from bs4 import BeautifulSoup as BS
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
from datetime import datetime
import time

# %%
# Begin timing
start_time = datetime.now()

# %%
# Set the executable path and initialize Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', headless=True)

# %%
# Visit the 'CIA World Factbook' site
url = 'https://www.cia.gov/the-world-factbook/countries/'
browser.visit(url)

# %%
# Locate the country links on each page

# Create variables for the links and text
c_links = []
c_txt = []

# Parse the HTML on each page and collect the country urls
for i in range(22):
    time.sleep(2)
    html = browser.html
    html_soup = BS(html, 'html.parser')

    country_row = html_soup.find('div', class_='col-lg-9 col-md-12 col-sm-12')
    for url in country_row.find_all('a'):
        pg_link = url.get('href')
        # print(pg_link)
        txt = url.get_text()

        # Skip the US Pacific Island Wildlife Refuges
        if 'united-states-pacific-island-wildlife-refuges' in pg_link:
            continue
            
        # Replace the segmented country names
        if 'World' in txt:
            continue
        elif 'West Bank' in txt:
            continue
        elif 'Venezuela' in txt:
            txt = 'Venezuela'
        elif 'Tanzania' in txt:
            txt = 'Tanzania'
        elif 'Hong Kong' in txt:
            txt = 'Hong Kong (China)'
        elif 'Congo, Democratic' in txt:
            txt = 'Democratic Republic of the Congo'

        c_links.append(pg_link)
        c_txt.append(txt)
        
    # Locate the next country page button and advance
    browser.find_by_css('.pagination__arrow-right').click()
# Out:
# /the-world-factbook/countries/afghanistan/
# /the-world-factbook/countries/akrotiri/
# /the-world-factbook/countries/albania/
# /the-world-factbook/countries/algeria/
# /the-world-factbook/countries/american-samoa/
# /the-world-factbook/countries/andorra/
# /the-world-factbook/countries/angola/
# /the-world-factbook/countries/anguilla/
# /the-world-factbook/countries/antarctica/
# /the-world-factbook/countries/antigua-and-barbuda/
# /the-world-factbook/countries/argentina/
# /the-world-factbook/countries/armenia/
# /the-world-factbook/countries/aruba/
# /the-world-factbook/countries/ashmore-and-cartier-islands/
# /the-world-factbook/countries/australia/
# /the-world-factbook/countries/austria/
# /the-world-factbook/countries/azerbaijan/
# /the-world-factbook/countries/bahamas-the/
# /the-world-factbook/countries/bahrain/
# /the-world-factbook/countries/united-states-pacific-island-wildlife-refuges/
# /the-world-factbook/countries/bangladesh/
# /the-world-factbook/countries/barbados/
# /the-world-factbook/countries/belarus/
# /the-world-factbook/countries/belgium/
# /the-world-factbook/countries/belize/
# /the-world-factbook/countries/benin/
# /the-world-factbook/countries/bermuda/
# /the-world-factbook/countries/bhutan/
# /the-world-factbook/countries/bolivia/
# /the-world-factbook/countries/bosnia-and-herzegovina/
# /the-world-factbook/countries/botswana/
# /the-world-factbook/countries/bouvet-island/
# /the-world-factbook/countries/brazil/
# /the-world-factbook/countries/british-indian-ocean-territory/
# /the-world-factbook/countries/british-virgin-islands/
# /the-world-factbook/countries/brunei/
# /the-world-factbook/countries/bulgaria/
# /the-world-factbook/countries/burkina-faso/
# /the-world-factbook/countries/burma/
# /the-world-factbook/countries/burundi/
# /the-world-factbook/countries/cabo-verde/
# /the-world-factbook/countries/cambodia/
# /the-world-factbook/countries/cameroon/
# /the-world-factbook/countries/canada/
# /the-world-factbook/countries/cayman-islands/
# /the-world-factbook/countries/central-african-republic/
# /the-world-factbook/countries/chad/
# /the-world-factbook/countries/chile/
# /the-world-factbook/countries/china/
# /the-world-factbook/countries/christmas-island/
# /the-world-factbook/countries/clipperton-island/
# /the-world-factbook/countries/cocos-keeling-islands/
# /the-world-factbook/countries/colombia/
# /the-world-factbook/countries/comoros/
# /the-world-factbook/countries/congo-democratic-republic-of-the/
# /the-world-factbook/countries/congo-republic-of-the/
# /the-world-factbook/countries/cook-islands/
# /the-world-factbook/countries/coral-sea-islands/
# /the-world-factbook/countries/costa-rica/
# /the-world-factbook/countries/cote-divoire/
# /the-world-factbook/countries/croatia/
# /the-world-factbook/countries/cuba/
# /the-world-factbook/countries/curacao/
# /the-world-factbook/countries/cyprus/
# /the-world-factbook/countries/czechia/
# /the-world-factbook/countries/denmark/
# /the-world-factbook/countries/dhekelia/
# /the-world-factbook/countries/djibouti/
# /the-world-factbook/countries/dominica/
# /the-world-factbook/countries/dominican-republic/
# /the-world-factbook/countries/ecuador/
# /the-world-factbook/countries/egypt/
# /the-world-factbook/countries/el-salvador/
# /the-world-factbook/countries/equatorial-guinea/
# /the-world-factbook/countries/eritrea/
# /the-world-factbook/countries/estonia/
# /the-world-factbook/countries/eswatini/
# /the-world-factbook/countries/ethiopia/
# /the-world-factbook/countries/european-union/
# /the-world-factbook/countries/falkland-islands-islas-malvinas/
# /the-world-factbook/countries/faroe-islands/
# /the-world-factbook/countries/fiji/
# /the-world-factbook/countries/finland/
# /the-world-factbook/countries/france/
# /the-world-factbook/countries/french-polynesia/
# /the-world-factbook/countries/french-southern-and-antarctic-lands/
# /the-world-factbook/countries/gabon/
# /the-world-factbook/countries/gambia-the/
# /the-world-factbook/countries/gaza-strip/
# /the-world-factbook/countries/georgia/
# /the-world-factbook/countries/germany/
# /the-world-factbook/countries/ghana/
# /the-world-factbook/countries/gibraltar/
# /the-world-factbook/countries/greece/
# /the-world-factbook/countries/greenland/
# /the-world-factbook/countries/grenada/
# /the-world-factbook/countries/guam/
# /the-world-factbook/countries/guatemala/
# /the-world-factbook/countries/guernsey/
# /the-world-factbook/countries/guinea/
# /the-world-factbook/countries/guinea-bissau/
# /the-world-factbook/countries/guyana/
# /the-world-factbook/countries/haiti/
# /the-world-factbook/countries/heard-island-and-mcdonald-islands/
# /the-world-factbook/countries/holy-see-vatican-city/
# /the-world-factbook/countries/honduras/
# /the-world-factbook/countries/hong-kong/
# /the-world-factbook/countries/united-states-pacific-island-wildlife-refuges/
# /the-world-factbook/countries/hungary/
# /the-world-factbook/countries/iceland/
# /the-world-factbook/countries/india/
# /the-world-factbook/countries/indonesia/
# /the-world-factbook/countries/iran/
# /the-world-factbook/countries/iraq/
# /the-world-factbook/countries/ireland/
# /the-world-factbook/countries/isle-of-man/
# /the-world-factbook/countries/israel/
# /the-world-factbook/countries/italy/
# /the-world-factbook/countries/jamaica/
# /the-world-factbook/countries/jan-mayen/
# /the-world-factbook/countries/japan/
# /the-world-factbook/countries/united-states-pacific-island-wildlife-refuges/
# /the-world-factbook/countries/jersey/
# /the-world-factbook/countries/united-states-pacific-island-wildlife-refuges/
# /the-world-factbook/countries/jordan/
# /the-world-factbook/countries/kazakhstan/
# /the-world-factbook/countries/kenya/
# /the-world-factbook/countries/united-states-pacific-island-wildlife-refuges/
# /the-world-factbook/countries/kiribati/
# /the-world-factbook/countries/korea-north/
# /the-world-factbook/countries/korea-south/
# /the-world-factbook/countries/kosovo/
# /the-world-factbook/countries/kuwait/
# /the-world-factbook/countries/kyrgyzstan/
# /the-world-factbook/countries/laos/
# /the-world-factbook/countries/latvia/
# /the-world-factbook/countries/lebanon/
# /the-world-factbook/countries/lesotho/
# /the-world-factbook/countries/liberia/
# /the-world-factbook/countries/libya/
# /the-world-factbook/countries/liechtenstein/
# /the-world-factbook/countries/lithuania/
# /the-world-factbook/countries/luxembourg/
# /the-world-factbook/countries/macau/
# /the-world-factbook/countries/madagascar/
# /the-world-factbook/countries/malawi/
# /the-world-factbook/countries/malaysia/
# /the-world-factbook/countries/maldives/
# /the-world-factbook/countries/mali/
# /the-world-factbook/countries/malta/
# /the-world-factbook/countries/marshall-islands/
# /the-world-factbook/countries/mauritania/
# /the-world-factbook/countries/mauritius/
# /the-world-factbook/countries/mexico/
# /the-world-factbook/countries/micronesia-federated-states-of/
# /the-world-factbook/countries/united-states-pacific-island-wildlife-refuges/
# /the-world-factbook/countries/moldova/
# /the-world-factbook/countries/monaco/
# /the-world-factbook/countries/mongolia/
# /the-world-factbook/countries/montenegro/
# /the-world-factbook/countries/montserrat/
# /the-world-factbook/countries/morocco/
# /the-world-factbook/countries/mozambique/
# /the-world-factbook/countries/namibia/
# /the-world-factbook/countries/nauru/
# /the-world-factbook/countries/navassa-island/
# /the-world-factbook/countries/nepal/
# /the-world-factbook/countries/netherlands/
# /the-world-factbook/countries/new-caledonia/
# /the-world-factbook/countries/new-zealand/
# /the-world-factbook/countries/nicaragua/
# /the-world-factbook/countries/niger/
# /the-world-factbook/countries/nigeria/
# /the-world-factbook/countries/niue/
# /the-world-factbook/countries/norfolk-island/
# /the-world-factbook/countries/north-macedonia/
# /the-world-factbook/countries/northern-mariana-islands/
# /the-world-factbook/countries/norway/
# /the-world-factbook/countries/oman/
# /the-world-factbook/countries/pakistan/
# /the-world-factbook/countries/palau/
# /the-world-factbook/countries/united-states-pacific-island-wildlife-refuges/
# /the-world-factbook/countries/panama/
# /the-world-factbook/countries/papua-new-guinea/
# /the-world-factbook/countries/paracel-islands/
# /the-world-factbook/countries/paraguay/
# /the-world-factbook/countries/peru/
# /the-world-factbook/countries/philippines/
# /the-world-factbook/countries/pitcairn-islands/
# /the-world-factbook/countries/poland/
# /the-world-factbook/countries/portugal/
# /the-world-factbook/countries/puerto-rico/
# /the-world-factbook/countries/qatar/
# /the-world-factbook/countries/romania/
# /the-world-factbook/countries/russia/
# /the-world-factbook/countries/rwanda/
# /the-world-factbook/countries/saint-barthelemy/
# /the-world-factbook/countries/saint-helena-ascension-and-tristan-da-cunha/
# /the-world-factbook/countries/saint-kitts-and-nevis/
# /the-world-factbook/countries/saint-lucia/
# /the-world-factbook/countries/saint-martin/
# /the-world-factbook/countries/saint-pierre-and-miquelon/
# /the-world-factbook/countries/saint-vincent-and-the-grenadines/
# /the-world-factbook/countries/samoa/
# /the-world-factbook/countries/san-marino/
# /the-world-factbook/countries/sao-tome-and-principe/
# /the-world-factbook/countries/saudi-arabia/
# /the-world-factbook/countries/senegal/
# /the-world-factbook/countries/serbia/
# /the-world-factbook/countries/seychelles/
# /the-world-factbook/countries/sierra-leone/
# /the-world-factbook/countries/singapore/
# /the-world-factbook/countries/sint-maarten/
# /the-world-factbook/countries/slovakia/
# /the-world-factbook/countries/slovenia/
# /the-world-factbook/countries/solomon-islands/
# /the-world-factbook/countries/somalia/
# /the-world-factbook/countries/south-africa/
# /the-world-factbook/countries/south-georgia-and-south-sandwich-islands/
# /the-world-factbook/countries/south-sudan/
# /the-world-factbook/countries/spain/
# /the-world-factbook/countries/spratly-islands/
# /the-world-factbook/countries/sri-lanka/
# /the-world-factbook/countries/sudan/
# /the-world-factbook/countries/suriname/
# /the-world-factbook/countries/svalbard/
# /the-world-factbook/countries/sweden/
# /the-world-factbook/countries/switzerland/
# /the-world-factbook/countries/syria/
# /the-world-factbook/countries/taiwan/
# /the-world-factbook/countries/tajikistan/
# /the-world-factbook/countries/tanzania/
# /the-world-factbook/countries/thailand/
# /the-world-factbook/countries/timor-leste/
# /the-world-factbook/countries/togo/
# /the-world-factbook/countries/tokelau/
# /the-world-factbook/countries/tonga/
# /the-world-factbook/countries/trinidad-and-tobago/
# /the-world-factbook/countries/tunisia/
# /the-world-factbook/countries/turkey-turkiye/
# /the-world-factbook/countries/turkmenistan/
# /the-world-factbook/countries/turks-and-caicos-islands/
# /the-world-factbook/countries/tuvalu/
# /the-world-factbook/countries/uganda/
# /the-world-factbook/countries/ukraine/
# /the-world-factbook/countries/united-arab-emirates/
# /the-world-factbook/countries/united-kingdom/
# /the-world-factbook/countries/united-states/
# /the-world-factbook/countries/united-states-pacific-island-wildlife-refuges/
# /the-world-factbook/countries/uruguay/
# /the-world-factbook/countries/uzbekistan/
# /the-world-factbook/countries/vanuatu/
# /the-world-factbook/countries/venezuela/
# /the-world-factbook/countries/vietnam/
# /the-world-factbook/countries/virgin-islands/
# /the-world-factbook/countries/wake-island/
# /the-world-factbook/countries/wallis-and-futuna/
# /the-world-factbook/countries/west-bank/
# /the-world-factbook/countries/world/
# /the-world-factbook/countries/yemen/
# /the-world-factbook/countries/zambia/
# /the-world-factbook/countries/zimbabwe/

# %%
len(c_links)

# %%
#len(c_txt)

# %%
# Build profile page urls
base_url = 'https://www.cia.gov'
data_date = []
gov_type = []
prof_urls = []

for lnk in c_links:
    time.sleep(10)
    new_url = base_url + lnk
    prof_urls.append(new_url)
    
    browser.visit(new_url)
    # Parse the HTML
    prof_html = browser.html
    prof_soup = BS(prof_html, 'html.parser')
    
    # Locate the date of last profile update
    prof_update = prof_soup.find('label', class_='header-subsection-date')
    data_date.append(prof_update.get_text())
    #print(data_date)

    # Locate the type of government
    try:
        prof_cont = prof_soup.find(lambda tag:tag.name=="a" and "Government type" in tag.text).next_element.next_element.get_text()
        #print(f'First try - : {prof_cont}')
    except:
        try:
            prof_cont = prof_soup.find(lambda tag:tag.name=="a" and "Diplomatic representation in the US" in tag.text).next_element.next_element.get_text()
            # print(f'Exception try - : {prof_cont}')
        except:
            try:
                prof_cont = prof_soup.find(lambda tag:tag.name=="a" and "Independence" in tag.text).next_element.next_element.get_text()
                # print(f'Exception try 2 - : {prof_cont}')
            except:
                try:
                    prof_cont = prof_soup.find(lambda tag:tag.name=="a" and "Dependency status" in tag.text).next_element.next_element.get_text()
                    # print(f'Exception try 3 - : {prof_cont}')
                except:
                    prof_cont = 'unknown'

    # print(prof_cont)
    gov_type.append(prof_cont)

# %%
end_time = datetime.now()
print('Data Collection Duration: {}'.format(end_time - start_time))
# Out:
# Data Collection Duration: 0:45:56.925458

# %%
gov_type
# Out:
# ['theocratic; the United States does not recognize the Taliban Government',
#  'none (overseas territory of the UK)',
#  'parliamentary republic',
#  'presidential republic',
#  'unincorporated, unorganized Territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches',
#  "parliamentary democracy (since March 1993) that retains its chiefs of state in the form of a co-principality; the two princes are the President of France and Bishop of Seu d'Urgell, Spain",
#  'presidential republic',
#  'parliamentary democracy (House of Assembly); self-governing overseas territory of the UK',
#  '',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'presidential republic',
#  'parliamentary democracy; note - constitutional changes adopted in December 2015 transformed the government to a parliamentary system',
#  'parliamentary democracy; part of the Kingdom of the Netherlands',
#  'none (territory of Australia)',
#  'federal parliamentary democracy\xa0under a constitutional monarchy; a Commonwealth realm',
#  'federal parliamentary republic',
#  'presidential republic',
#  'parliamentary democracy\xa0under a constitutional monarchy; a Commonwealth realm',
#  'constitutional monarchy',
#  'parliamentary republic',
#  'parliamentary republic; a Commonwealth realm',
#  'presidential republic in name, although in fact a dictatorship',
#  'federal parliamentary democracy under a constitutional monarchy',
#  'parliamentary democracy (National Assembly) under a constitutional monarchy; a Commonwealth realm',
#  'presidential republic',
#  'Overseas Territory of the UK with limited self-government; parliamentary democracy',
#  'constitutional monarchy',
#  'presidential republic',
#  'parliamentary republic',
#  'parliamentary republic',
#  'territory of Norway; administered by the Polar Department of the Ministry of Justice and Oslo Police',
#  'federal presidential republic',
#  'none (overseas territory of the UK)',
#  'Overseas Territory of the UK with limited self-government; parliamentary democracy',
#  'absolute monarchy or sultanate',
#  'parliamentary republic',
#  'presidential republic',
#  'parliamentary republic',
#  'presidential republic',
#  'parliamentary republic',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'federal parliamentary democracy (Parliament of Canada) under a constitutional monarchy; a Commonwealth realm; federal and state authorities and responsibilities regulated in constitution',
#  'parliamentary democracy; self-governing overseas territory of the UK',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'communist party-led state',
#  'non-self-governing overseas territory of Australia',
#  'possession of France; administered directly by the Minister of Overseas France',
#  'non-self-governing overseas territory of Australia',
#  'presidential republic',
#  'federal presidential republic',
#  'semi-presidential republic',
#  'presidential republic',
#  'parliamentary democracy',
#  'none (territory of Australia)',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary republic',
#  'communist state',
#  '',
#  'Republic of Cyprus - presidential republic; self-declared "Turkish Republic of Northern Cyprus" (TRNC) - parliamentary republic with enhanced presidencynote: a separation of the two main ethnic communities inhabiting the island began following the outbreak of communal strife in 1963; this separation was further solidified when a Greek military-junta-supported coup attempt prompted the Turkish military intervention in July 1974 that gave the Turkish Cypriots de facto control in the north; Greek Cypriots control the only internationally recognized government on the island; on 15 November 1983, then Turkish Cypriot "President" Rauf DENKTAS declared independence and the formation of the "TRNC,” which is recognized only by Turkey',
#  'parliamentary republic',
#  'parliamentary constitutional monarchy',
#  'none (overseas territory of the UK)',
#  'presidential republic',
#  'parliamentary republic',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary republic',
#  'absolute monarchy',
#  'federal parliamentary republic',
#  'chief of mission: Ambassador Stavros LAMBRINIDIS (since 8 April 2019)chancery: 2175 K Street NW, Washington, DC 20037telephone: [1] (202) 862-9500FAX: [1] (202) 429-1766email address and website: delegation-usa-info@eeas.europa.euDelegation of the European Union to the United States of America | EEAS (europa.eu)',
#  'parliamentary democracy (Legislative Assembly); self-governing overseas territory of the UK',
#  'parliamentary democracy (Faroese Parliament); part of the Kingdom of Denmark',
#  'parliamentary republic',
#  'parliamentary republic',
#  'semi-presidential republic',
#  'parliamentary democracy (Assembly of French Polynesia); an overseas collectivity of France',
#  'none (overseas territory of France)',
#  'presidential republic',
#  'presidential republic',
#  'unknown',
#  'semi-presidential republic',
#  'federal parliamentary republic',
#  'presidential republic',
#  'parliamentary democracy (Parliament); self-governing overseas territory of the UK',
#  'parliamentary republic',
#  'parliamentary democracy (Parliament of Greenland or Inatsisartut)',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches',
#  'presidential republic',
#  'parliamentary democracy (States of Deliberation)',
#  'presidential republic',
#  'semi-presidential republic',
#  'parliamentary republic',
#  'semi-presidential republic',
#  'none (territory of Australia)',
#  'ecclesiastical elective monarchy; self-described as an "absolute monarchy"',
#  'presidential republic',
#  "presidential limited democracy; a special administrative region of the People's Republic of China",
#  'parliamentary republic',
#  'unitary parliamentary republic',
#  'federal parliamentary republic',
#  'presidential republic',
#  'theocratic republic',
#  'federal parliamentary republic',
#  'parliamentary republic',
#  'parliamentary democracy (Tynwald)',
#  'parliamentary democracy',
#  'parliamentary republic',
#  'parliamentary democracy (Parliament) under a constitutional monarchy; a Commonwealth realm',
#  'territory of Norway; since August 1994, administered from Oslo through the county governor (fylkesmann) of Nordland; however, authority has been delegated to a station commander of the Norwegian Defense Communication Service; in 2010, Norway designated the majority of Jan Mayen as a nature reserve',
#  'parliamentary constitutional monarchy',
#  'parliamentary democracy (Assembly of the States of Jersey)',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'dictatorship, single-party state; official state ideology of "Juche" or "national self-reliance"',
#  'presidential republic',
#  'parliamentary republic',
#  'constitutional monarchy (emirate)',
#  'parliamentary republic',
#  'communist state',
#  'parliamentary republic',
#  'parliamentary republic',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'in transition',
#  'constitutional monarchy',
#  'semi-presidential republic',
#  'constitutional monarchy',
#  "executive-led limited democracy; a special administrative region of the People's Republic of China",
#  'semi-presidential republic',
#  'presidential republic',
#  'federal parliamentary constitutional monarchynote: all Peninsular Malaysian states have hereditary rulers (commonly referred to as sultans) except Melaka (Malacca) and Pulau Pinang (Penang); those two states along with Sabah and Sarawak in East Malaysia have governors appointed by government; powers of state governments are limited by the federal constitution; under terms of federation, Sabah and Sarawak retain certain constitutional prerogatives (e.g., right to maintain their own immigration controls)',
#  'presidential republic',
#  'semi-presidential republic',
#  'parliamentary republic',
#  'mixed presidential-parliamentary system in free association with the US',
#  'presidential republic',
#  'parliamentary republic',
#  'federal presidential republic',
#  'federal republic in free association with the US',
#  'parliamentary republic',
#  'constitutional monarchy',
#  'semi-presidential republic',
#  'parliamentary republic',
#  'parliamentary democracy; self-governing overseas territory of the UK',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary republic',
#  'unorganized, unincorporated territory of the US; administered by the Fish and Wildlife Service, US Department of the Interior from the Caribbean Islands National Wildlife Refuge in Boqueron, Puerto Rico; in September 1996, the Coast Guard ceased operations and maintenance of the Navassa Island Light, a 46-meter-tall lighthouse on the southern side of the island; Haiti has claimed the island since the 19th century',
#  'federal parliamentary republic',
#  'parliamentary constitutional monarchy; part of the Kingdom of the Netherlands',
#  'parliamentary democracy (Territorial Congress); an overseas collectivity of France',
#  'parliamentary democracy\xa0under a constitutional monarchy; a Commonwealth realm',
#  'presidential republic',
#  'semi-presidential republic',
#  'federal presidential republic',
#  'parliamentary democracy',
#  'non-self-governing overseas territory of Australia; note - the Norfolk Island Regional Council, which began operations 1 July 2016, is responsible for planning and managing a variety of public services, including those funded by the Government of Australia',
#  'parliamentary republic',
#  'a commonwealth in political union with and under the sovereignty of the US; republican form of government with separate executive, legislative, and judicial branches',
#  'parliamentary constitutional monarchy',
#  'absolute monarchy',
#  'federal parliamentary republic',
#  'presidential republic in free association with the US',
#  'presidential republic',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'unknown',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary democracy',
#  'parliamentary republic',
#  'semi-presidential republic',
#  'unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches; note - reference Puerto Rican Federal Relations Act, 2 March 1917, as amended by Public Law 600, 3 July 1950',
#  'absolute monarchy',
#  'semi-presidential republic',
#  'semi-presidential federation',
#  'presidential republic',
#  'parliamentary democracy (Territorial Council); overseas collectivity of France',
#  'parliamentary democracy',
#  'federal parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'parliamentary democracy (Territorial Council); overseas collectivity of France',
#  'parliamentary democracy (Territorial Council); overseas collectivity of France',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'parliamentary republic',
#  'parliamentary republic',
#  'semi-presidential republic',
#  'absolute monarchy',
#  'presidential republic',
#  'parliamentary republic',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary republic',
#  '',
#  'parliamentary republic',
#  'parliamentary republic',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'federal parliamentary republic',
#  'parliamentary republic',
#  'none (overseas territory of the UK, also claimed by Argentina)',
#  'presidential republic',
#  'parliamentary constitutional monarchy',
#  'unknown',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'non-self-governing territory of Norway',
#  'parliamentary constitutional monarchy',
#  'federal republic (formally a confederation)',
#  'presidential republic; highly authoritarian regime',
#  'semi-presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'constitutional monarchy',
#  'semi-presidential republic',
#  'presidential republic',
#  '',
#  'constitutional monarchy',
#  'parliamentary republic',
#  'parliamentary republic',
#  'presidential republic',
#  'presidential republic; authoritarian',
#  'parliamentary democracy',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'presidential republic',
#  'semi-presidential republic',
#  'federation of monarchies',
#  'parliamentary constitutional monarchy; a Commonwealth realm',
#  'constitutional federal republic',
#  'presidential republic',
#  'presidential republic; highly authoritarian',
#  'parliamentary republic',
#  'federal presidential republic',
#  'communist state',
#  'unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches',
#  'none (territory of the US)',
#  'parliamentary democracy (Territorial Assembly); overseas collectivity of France',
#  'in transition',
#  'presidential republic',
#  'presidential republic']

# %%
# Convert the lists to DataFrames
data_date_ser = pd.Series(data_date)                                                                                                                             
data_date_df = data_date_ser.to_frame()

gov_type_ser = pd.Series(gov_type)                                                                                                                             
gov_type_df = gov_type_ser.to_frame()

prof_urls_ser = pd.Series(prof_urls)                                                                                                                             
prof_urls_df = prof_urls_ser.to_frame()

c_txt_ser = pd.Series(c_txt)                                                                                                                             
c_txt_df = c_txt_ser.to_frame()

# %%
data_date_df
# Out:
#                                       0
# 0    Page last updated: August 01, 2023
# 1      Page last updated: July 11, 2023
# 2      Page last updated: July 25, 2023
# 3    Page last updated: August 01, 2023
# 4      Page last updated: July 25, 2023
# ..                                  ...
# 247    Page last updated: July 25, 2023
# 248    Page last updated: July 24, 2023
# 249    Page last updated: July 25, 2023
# 250    Page last updated: July 31, 2023
# 251  Page last updated: August 01, 2023
#
# [252 rows x 1 columns]

# %%
# Merge the DataFrames and rename the columns
country_government_df = c_txt_df.merge(gov_type_df, left_index=True, right_index=True)

country_government_df = country_government_df.rename({'0_x': 'country', '0_y': 'government_type'}, axis=1)

country_government_df
# Out:
#                country                                    government_type
# 0          Afghanistan  theocratic; the United States does not recogni...
# 1             Akrotiri                none (overseas territory of the UK)
# 2              Albania                             parliamentary republic
# 3              Algeria                              presidential republic
# 4       American Samoa  unincorporated, unorganized Territory of the U...
# ..                 ...                                                ...
# 247        Wake Island                         none (territory of the US)
# 248  Wallis and Futuna  parliamentary democracy (Territorial Assembly)...
# 249              Yemen                                      in transition
# 250             Zambia                              presidential republic
# 251           Zimbabwe                              presidential republic
#
# [252 rows x 2 columns]

# %%
# Merge the DataFrames and rename the columns
country_government_df = country_government_df.merge(data_date_df, left_index=True, right_index=True)

country_government_df = country_government_df.rename({'country': 'country', 'government_type': 'government_type', '0': 'profile_data_date'}, axis=1)

country_government_df
# Out:
#                country                                    government_type  \
# 0          Afghanistan  theocratic; the United States does not recogni...
# 1             Akrotiri                none (overseas territory of the UK)
# 2              Albania                             parliamentary republic
# 3              Algeria                              presidential republic
# 4       American Samoa  unincorporated, unorganized Territory of the U...
# ..                 ...                                                ...
# 247        Wake Island                         none (territory of the US)
# 248  Wallis and Futuna  parliamentary democracy (Territorial Assembly)...
# 249              Yemen                                      in transition
# 250             Zambia                              presidential republic
# 251           Zimbabwe                              presidential republic
#
#                                       0
# 0    Page last updated: August 01, 2023
# 1      Page last updated: July 11, 2023
# 2      Page last updated: July 25, 2023
# 3    Page last updated: August 01, 2023
# 4      Page last updated: July 25, 2023
# ..                                  ...
# 247    Page last updated: July 25, 2023
# 248    Page last updated: July 24, 2023
# 249    Page last updated: July 25, 2023
# 250    Page last updated: July 31, 2023
# 251  Page last updated: August 01, 2023
#
# [252 rows x 3 columns]

# %%
country_government_df.to_csv('country_government_systems.csv', index=False)

# %%
country_name_df = c_txt_df

# %%
# Merge the DataFrames and rename the columns
country_urls_df = country_name_df.merge(prof_urls_df, left_index=True, right_index=True)

country_urls_df  = country_urls_df .rename({'0_x': 'country', '0_y': 'profile_url'}, axis=1)

country_urls_df
# Out:
#                country                                        profile_url
# 0          Afghanistan  https://www.cia.gov/the-world-factbook/countri...
# 1             Akrotiri  https://www.cia.gov/the-world-factbook/countri...
# 2              Albania  https://www.cia.gov/the-world-factbook/countri...
# 3              Algeria  https://www.cia.gov/the-world-factbook/countri...
# 4       American Samoa  https://www.cia.gov/the-world-factbook/countri...
# ..                 ...                                                ...
# 247        Wake Island  https://www.cia.gov/the-world-factbook/countri...
# 248  Wallis and Futuna  https://www.cia.gov/the-world-factbook/countri...
# 249              Yemen  https://www.cia.gov/the-world-factbook/countri...
# 250             Zambia  https://www.cia.gov/the-world-factbook/countri...
# 251           Zimbabwe  https://www.cia.gov/the-world-factbook/countri...
#
# [252 rows x 2 columns]

# %%
country_urls_df.to_csv('country_government_urls.csv', index=False)
