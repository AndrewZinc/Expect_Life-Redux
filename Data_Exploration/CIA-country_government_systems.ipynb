# %%
# Import Splinter, BeautifulSoup, and Pandas
from splinter import Browser
from bs4 import BeautifulSoup as BS
import pandas as pd
#from webdriver_manager.chrome import ChromeDriverManager
from datetime import datetime
import time

# %%
# Begin timing
start_time = datetime.now()

# %%
# Set the executable path and initialize Splinter
#executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome')

# %%
# Visit the 'CIA World Factbook' site
url = 'https://www.cia.gov/the-world-factbook/countries/'
browser.visit(url)

# %%
# Locate the country links on each page

# Create variables for the links and text
c_links = []
c_txt = []

# Parse the HTML on each page and collect the country urls
for i in range(22):
    time.sleep(2)
    html = browser.html
    html_soup = BS(html, 'html.parser')
    #print(html_soup)
    country_row = html_soup.find('div', class_='col-lg-9')
    #print(country_row)
    for url in country_row.find_all('a'):
        pg_link = url.get('href')
        # print(pg_link)
        txt = url.get_text()

        # Skip the US Pacific Island Wildlife Refuges
        if 'united-states-pacific-island-wildlife-refuges' in pg_link:
            continue
            
        # Replace the segmented country names
        if 'World' in txt:
            continue
        elif 'West Bank' in txt:
            continue
        elif 'European Union' in txt:
            continue
        elif 'Venezuela' in txt:
            txt = 'Venezuela'
        elif 'Taiwan' in txt:
            txt = 'Taiwan (China)'
        elif 'Tanzania' in txt:
            txt = 'Tanzania'
        elif 'Micronesia' in txt:
            txt = 'Micronesia'              
        elif 'Korea, South' in txt:
            txt = 'South Korea'  
        elif 'Korea, North' in txt:
            txt = 'North Korea'            
        elif 'Hong Kong' in txt:
            txt = 'Hong Kong (China)'
        elif 'Gambia' in txt:
            txt = 'Gambia'
        elif 'Congo, Republic' in txt:
            txt = 'Republic of the Congo'
        elif 'Congo, Democratic' in txt:
            txt = 'Democratic Republic of the Congo'
        elif 'Bahamas' in txt:
            txt = 'Bahamas'

        c_links.append(pg_link)
        c_txt.append(txt)
        
    # Locate the next country page button and advance
    browser.find_by_css('.pagination__arrow-right').click()

# %%
len(c_links)
# Out:
# 250

# %%
len(c_txt)
# Out:
# 250

# %%
# Build profile page urls
base_url = 'https://www.cia.gov'
data_date = []
gov_type = []
prof_urls = []

for lnk in c_links:
    time.sleep(2)
    new_url = base_url + lnk
    prof_urls.append(new_url)
    
    browser.visit(new_url)
    time.sleep(15)
    # Parse the HTML
    prof_html = browser.html
    prof_soup = BS(prof_html, 'html.parser')
    
    # Locate the date of last profile update
    prof_update = prof_soup.find('label', class_='header-subsection-date')
    data_date.append(prof_update.get_text())
    #print(data_date)

    # Locate the type of government
    try:
        prof_cont = prof_soup.find(lambda tag:tag.name=="a" and "Government type" in tag.text).next_element.next_element.get_text()
        print(f'First try - : {prof_cont}')
    except:
        try:
            prof_cont = prof_soup.find(lambda tag:tag.name=="a" and "Diplomatic representation in the US" in tag.text).next_element.next_element.get_text()
            print(f'Exception try - : {prof_cont}')
        except:
            try:
                prof_cont = prof_soup.find(lambda tag:tag.name=="a" and "Independence" in tag.text).next_element.next_element.get_text()
                print(f'Exception try 2 - : {prof_cont}')
            except:
                try:
                    prof_cont = prof_soup.find(lambda tag:tag.name=="a" and "Dependency status" in tag.text).next_element.next_element.get_text()
                    print(f'Exception try 3 - : {prof_cont}')
                except:
                    prof_cont = 'unknown'

    # print(prof_cont)
    gov_type.append(prof_cont)
# Out:
# First try - : theocratic; the United States does not recognize the Taliban Government
# Exception try - : none (overseas territory of the UK)
# First try - : parliamentary republic
# First try - : presidential republic
# First try - : unincorporated, unorganized Territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches
# First try - : parliamentary democracy (since March 1993) that retains its chiefs of state in the form of a co-principality; the two princes are the President of France and Bishop of Seu d'Urgell, Spain
# First try - : presidential republic
# First try - : parliamentary democracy (House of Assembly); self-governing overseas territory of the UK
# First try - : Antarctic Treaty Summary - the Antarctic region is governed by a system known as the Antarctic Treaty system; the system includes: 1. the Antarctic Treaty, signed on 1 December 1959 and entered into force on 23 June 1961, which establishes the legal framework for the management of Antarctica, 2. Measures, Decisions, and Resolutions adopted at Antarctic Treaty Consultative Meetings, 3. The Convention for the Conservation of Antarctic Seals (1972), 4. The Convention on the Conservation of Antarctic Marine Living Resources (1980), and 5. The Protocol on Environmental Protection to the Antarctic Treaty (1991); the Antarctic Treaty Consultative Meetings operate by consensus (not by vote) of all consultative parties at annual Treaty meetings; by January 2024, there were 56 treaty member nations: 29 consultative and 27 non-consultative; consultative (decision-making) members include the seven nations that claim portions of Antarctica as national territory (some claims overlap) and 22 non-claimant nations; the US and Russia have reserved the right to make claims; the US does not recognize the claims of others; Antarctica is administered through meetings of the consultative member nations; measures adopted at these meetings are carried out by these member nations (with respect to their own nationals and operations) in accordance with their own national laws; the years in parentheses indicate when a consultative member-nation acceded to the Treaty and when it was accepted as a consultative member, while no date indicates the country was an original 1959 treaty signatory; claimant nations are - Argentina, Australia, Chile, France, NZ, Norway, and the UK; nonclaimant consultative nations are - Belgium, Brazil (1975/1983), Bulgaria (1978/1998), China (1983/1985), Czechia (1962/2014), Ecuador (1987/1990), Finland (1984/1989), Germany (1979/1981), India (1983/1983), Italy (1981/1987), Japan, South Korea (1986/1989), Netherlands (1967/1990), Peru (1981/1989), Poland (1961/1977), Russia, South Africa, Spain (1982/1988), Sweden (1984/1988), Ukraine (1992/2004), Uruguay (1980/1985), and the US; non-consultative members, with year of accession in parentheses, are - Austria (1987), Belarus (2006), Canada (1988), Colombia (1989), Costa Rica (2022) Cuba (1984), Denmark (1965), Estonia (2001), Greece (1987), Guatemala (1991), Hungary (1984), Iceland (2015), Kazakhstan (2015), North Korea (1987), Malaysia (2011), Monaco (2008), Mongolia (2015), Pakistan (2012), Papua New Guinea (1981), Portugal (2010), Romania (1971), San Marino (2023), Slovakia (1962/1993), Slovenia (2019), Switzerland (1990), Turkey (1996), and Venezuela (1999); note - Czechoslovakia acceded to the Treaty in 1962 and separated into the Czech Republic and Slovakia in 1993; Article 1 - area to be used for peaceful purposes only; military activity, such as weapons testing, is prohibited, but military personnel and equipment may be used for scientific research or any other peaceful purpose; Article 2 - freedom of scientific investigation and cooperation shall continue; Article 3 - free exchange of information and personnel, cooperation with the UN and other international agencies; Article 4 - does not recognize, dispute, or establish territorial claims and no new claims shall be asserted while the treaty is in force; Article 5 - prohib
# First try - : parliamentary democracy under a constitutional monarchy; a Commonwealth realm
# First try - : unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches
# First try - : presidential republic
# First try - : parliamentary democracy (States of Deliberation)
# First try - : presidential republic
# First try - : semi-presidential republic
# First try - : parliamentary republic
# First try - : semi-presidential republic
# Exception try - : none (territory of Australia)
# First try - : ecclesiastical elective monarchy; self-described as an "absolute monarchy"
# First try - : presidential republic
# First try - : presidential limited democracy; a special administrative region of the People's Republic of China
# First try - : parliamentary republic
# First try - : unitary parliamentary republic
# First try - : federal parliamentary republic
# First try - : presidential republic
# First try - : theocratic republic
# First try - : federal parliamentary republic
# First try - : parliamentary republic
# First try - : parliamentary democracy (Tynwald)
# First try - : parliamentary democracy
# First try - : parliamentary republic
# First try - : parliamentary democracy (Parliament) under a constitutional monarchy; a Commonwealth realm
# Exception try 3 - : territory of Norway; since August 1994, administered from Oslo through the county governor (fylkesmann) of Nordland; however, authority has been delegated to a station commander of the Norwegian Defense Communication Service; in 2010, Norway designated the majority of Jan Mayen as a nature reserve
# First try - : parliamentary constitutional monarchy
# First try - : parliamentary democracy (Assembly of the States of Jersey)
# First try - : parliamentary constitutional monarchy
# First try - : presidential republic
# First try - : presidential republic
# First try - : presidential republic
# First try - : dictatorship, single-party communist state
# First try - : presidential republic
# First try - : parliamentary republic
# First try - : constitutional monarchy (emirate)
# First try - : parliamentary republic
# First try - : communist party-led state
# First try - : parliamentary republic
# First try - : parliamentary democratic republic
# First try - : parliamentary constitutional monarchy
# First try - : presidential republic
# First try - : in transition
# First try - : constitutional monarchy
# First try - : semi-presidential republic
# First try - : constitutional monarchy
# First try - : executive-led limited democracy; a special administrative region of the People's Republic of China
# First try - : semi-presidential republic
# First try - : presidential republic
# First try - : federal parliamentary constitutional monarchynote: all Peninsular Malaysian states have hereditary rulers (commonly referred to as sultans) except Melaka (Malacca) and Pulau Pinang (Penang); those two states along with Sabah and Sarawak in East Malaysia have governors appointed by government; powers of state governments are limited by the federal constitution; under terms of federation, Sabah and Sarawak retain certain constitutional prerogatives (e.g., right to maintain their own immigration controls)
# First try - : presidential republic
# First try - : semi-presidential republic
# First try - : parliamentary republic
# First try - : mixed presidential-parliamentary system in free association with the US
# First try - : presidential republic
# First try - : parliamentary republic
# First try - : federal presidential republic
# First try - : federal republic in free association with the US
# First try - : parliamentary republic
# First try - : constitutional monarchy
# First try - : semi-presidential republic
# First try - : parliamentary republic
# First try - : parliamentary democracy; self-governing overseas territory of the UK
# First try - : parliamentary constitutional monarchy
# First try - : presidential republic
# First try - : presidential republic
# First try - : parliamentary republic
# Exception try 3 - : unorganized, unincorporated territory of the US; administered by the Fish and Wildlife Service, US Department of the Interior from the Caribbean Islands National Wildlife Refuge in Boqueron, Puerto Rico; in September 1996, the Coast Guard ceased operations and maintenance of the Navassa Island Light, a 46-meter-tall lighthouse on the southern side of the island; Haiti has claimed the island since the 19th century
# First try - : federal parliamentary republic
# First try - : parliamentary constitutional monarchy; part of the Kingdom of the Netherlands
# First try - : parliamentary democracy (Territorial Congress); an overseas collectivity of France
# First try - : parliamentary democracy under a constitutional monarchy; a Commonwealth realm
# First try - : presidential republic
# First try - : formerly, semi-presidential republicNote: on 26 July 2023, the National Council for the Safeguard of the Homeland, a military junta which took control of Niger's government, dissolved all government institutions, and rules by decree
# First try - : federal presidential republic
# First try - : parliamentary democracy
# First try - : non-self-governing overseas territory of Australia; note - the Norfolk Island Regional Council, which began operations 1 July 2016, is responsible for planning and managing a variety of public services, including those funded by the Government of Australia
# First try - : parliamentary republic
# First try - : a commonwealth in political union with and under the sovereignty of the US; republican form of government with separate executive, legislative, and judicial branches
# First try - : parliamentary constitutional monarchy
# First try - : absolute monarchy
# First try - : federal parliamentary republic
# First try - : presidential republic in free association with the US
# First try - : presidential republic
# First try - : parliamentary democracy under a constitutional monarchy; a Commonwealth realm
# First try - : presidential republic
# First try - : presidential republic
# First try - : presidential republic
# First try - : parliamentary democracy
# First try - : parliamentary republic
# First try - : semi-presidential republic
# First try - : unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches; note - reference Puerto Rican Federal Relations Act, 2 March 1917, as amended by Public Law 600, 3 July 1950
# First try - : absolute monarchy
# First try - : semi-presidential republic
# First try - : semi-presidential federation
# First try - : presidential republic
# First try - : parliamentary democracy (Territorial Council); overseas collectivity of France
# First try - : parliamentary democracy
# First try - : federal parliamentary democracy under a constitutional monarchy; a Commonwealth realm
# First try - : parliamentary democracy under a constitutional monarchy; a Commonwealth realm
# First try - : parliamentary democracy (Territorial Council); overseas collectivity of France
# First try - : parliamentary democracy (Territorial Council); overseas collectivity of France
# First try - : parliamentary democracy under a constitutional monarchy; a Commonwealth realm
# First try - : parliamentary republic
# First try - : parliamentary republic
# First try - : semi-presidential republic
# First try - : absolute monarchy
# First try - : presidential republic
# First try - : parliamentary republic
# First try - : presidential republic
# First try - : presidential republic
# First try - : parliamentary republic
# First try - : parliamentary democracy under a constitutional monarchy
# First try - : parliamentary republic
# First try - : parliamentary republic
# First try - : parliamentary democracy under a constitutional monarchy; a Commonwealth realm
# First try - : federal parliamentary republic
# First try - : parliamentary republic
# Exception try - : none (administered by the UK, claimed by Argentina)
# First try - : presidential republic
# First try - : parliamentary constitutional monarchy
# First try - : presidential republic
# First try - : presidential republic
# First try - : presidential republic
# First try - : non-self-governing territory of Norway
# First try - : parliamentary constitutional monarchy
# First try - : federal republic (formally a confederation)
# First try - : presidential republic; highly authoritarian regime
# First try - : semi-presidential republic
# First try - : presidential republic
# First try - : presidential republic
# First try - : constitutional monarchy
# First try - : semi-presidential republic
# First try - : presidential republic
# First try - : parliamentary democracy under a constitutional monarchy
# First try - : constitutional monarchy
# First try - : parliamentary republic
# First try - : parliamentary republic
# First try - : presidential republic
# First try - : presidential republic; authoritarian
# First try - : parliamentary democracy
# First try - : parliamentary democracy under a constitutional monarchy; a Commonwealth realm
# First try - : presidential republic
# First try - : semi-presidential republic
# First try - : federation of monarchies
# First try - : parliamentary constitutional monarchy; a Commonwealth realm
# First try - : constitutional federal republic
# First try - : presidential republic
# First try - : presidential republic; highly authoritarian
# First try - : parliamentary republic
# First try - : federal presidential republic
# First try - : communist party-led state
# First try - : unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches
# Exception try 2 - : none (territory of the US)
# First try - : parliamentary democracy (Territorial Assembly); overseas collectivity of France
# First try - : in transition
# First try - : presidential republic
# First try - : presidential republic

# %%
end_time = datetime.now()
print('Data Collection Duration: {}'.format(end_time - start_time))
# Out:
# Data Collection Duration: 1:22:31.239603

# %%
gov_type
# Out:
# ['theocratic; the United States does not recognize the Taliban Government',
#  'none (overseas territory of the UK)',
#  'parliamentary republic',
#  'presidential republic',
#  'unincorporated, unorganized Territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial bran
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'presidential republic',
#  'parliamentary democracy; note - constitutional changes adopted in December 2015 transformed the government to a parliamentary system',
#  'parliamentary democracy; part of the Kingdom of the Netherlands',
#  'none (territory of Australia)',
#  'federal parliamentary democracy\xa0under a constitutional monarchy; a Commonwealth realm',
#  'federal parliamentary republic',
#  'presidential republic',
#  'parliamentary democracy\xa0under a constitutional monarchy; a Commonwealth realm',
#  'constitutional monarchy',
#  'parliamentary republic',
#  'parliamentary republic; a Commonwealth realm',
#  'presidential republic in name, although in fact a dictatorship',
#  'federal parliamentary democracy under a constitutional monarchy',
#  'parliamentary democracy (National Assembly) under a constitutional monarchy; a Commonwealth realm',
#  'presidential republic',
#  'Overseas Territory of the UK with limited self-government; parliamentary democracy',
#  'constitutional monarchy',
#  'presidential republic',
#  'parliamentary republic',
#  'parliamentary republic',
#  'territory of Norway; administered by the Polar Department of the Ministry of Justice and Oslo Police',
#  'federal presidential republic',
#  'none (overseas territory of the UK)',
#  'Overseas Territory of the UK with limited self-government; parliamentary democracy',
#  'absolute monarchy or sultanate',
#  'parliamentary republic',
#  'presidential republic',
#  'military regime',
#  'presidential republic',
#  'parliamentary republic',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'federal parliamentary democracy (Parliament of Canada) under a constitutional monarchy; a Commonwealth realm; federal and state authorities and responsibilities regulated in constitution',
#  'parliamentary democracy; self-governing overseas territory of the UK',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'communist party-led state',
#  'non-self-governing overseas territory of Australia',
#  'possession of France; administered directly by the Minister of Overseas France',
#  'non-self-governing overseas territory of Australia',
#  'presidential republic',
#  'federal presidential republic',
#  'semi-presidential republic',
#  'presidential republic',
#  'parliamentary democracy',
#  'none (territory of Australia)',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary republic',
#  'communist state',
#  'parliamentary democracy',
#  'Republic of Cyprus - presidential republic; self-declared "Turkish Republic of Northern Cyprus" (TRNC) - parliamentary republic with enhanced presidencynote: a separation of the two main ethnic communities inhabiting the island began following the outbreak of communal strife in 1963; this separation was further solidified when a Greek military-junta-supported coup attempt prompted the Turkish military intervention in July 1974 that gave the Turkish Cypriots de facto control in the north; Greek Cypriots control the only internationally recognized government on the island; on 15 November 1983, then Turkish Cypriot "President" Rauf DENKTAS declared independence and the formation of the "TRNC,” which is recognized only by Turkey',
#  'parliamentary republic',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'parliamentary republic',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary republic',
#  'absolute monarchy',
#  'federal parliamentary republic',
#  'parliamentary democracy (Legislative Assembly); self-governing overseas territory of the UK',
#  'parliamentary democracy (Faroese Parliament); part of the Kingdom of Denmark',
#  'parliamentary republic',
#  'parliamentary republic',
#  'semi-presidential republic',
#  'parliamentary democracy (Assembly of French Polynesia); an overseas collectivity of France',
#  'none (overseas territory of France)',
#  'presidential republic',
#  'presidential republic',
#  'unknown',
#  'semi-presidential republic',
#  'federal parliamentary republic',
#  'presidential republic',
#  'parliamentary democracy (Parliament); self-governing overseas territory of the UK',
#  'parliamentary republic',
#  'parliamentary democracy (Parliament of Greenland or Inatsisartut)',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches',
#  'presidential republic',
#  'parliamentary democracy (States of Deliberation)',
#  'presidential republic',
#  'semi-presidential republic',
#  'parliamentary republic',
#  'semi-presidential republic',
#  'none (territory of Australia)',
#  'ecclesiastical elective monarchy; self-described as an "absolute monarchy"',
#  'presidential republic',
#  "presidential limited democracy; a special administrative region of the People's Republic of China",
#  'parliamentary republic',
#  'unitary parliamentary republic',
#  'federal parliamentary republic',
#  'presidential republic',
#  'theocratic republic',
#  'federal parliamentary republic',
#  'parliamentary republic',
#  'parliamentary democracy (Tynwald)',
#  'parliamentary democracy',
#  'parliamentary republic',
#  'parliamentary democracy (Parliament) under a constitutional monarchy; a Commonwealth realm',
#  'territory of Norway; since August 1994, administered from Oslo through the county governor (fylkesmann) of Nordland; however, authority has been delegated to a station commander of the Norwegian Defense Communication Service; in 2010, Norway designated the majority of Jan Mayen as a nature reserve',
#  'parliamentary constitutional monarchy',
#  'parliamentary democracy (Assembly of the States of Jersey)',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'dictatorship, single-party communist state',
#  'presidential republic',
#  'parliamentary republic',
#  'constitutional monarchy (emirate)',
#  'parliamentary republic',
#  'communist party-led state',
#  'parliamentary republic',
#  'parliamentary democratic republic',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'in transition',
#  'constitutional monarchy',
#  'semi-presidential republic',
#  'constitutional monarchy',
#  "executive-led limited democracy; a special administrative region of the People's Republic of China",
#  'semi-presidential republic',
#  'presidential republic',
#  'federal parliamentary constitutional monarchynote: all Peninsular Malaysian states have hereditary rulers (commonly referred to as sultans) except Melaka (Malacca) and Pulau Pinang (Penang); those two states along with Sabah and Sarawak in East Malaysia have governors appointed by government; powers of state governments are limited by the federal constitution; under terms of federation, Sabah and Sarawak retain certain constitutional prerogatives (e.g., right to maintain their own immigration controls)',
#  'presidential republic',
#  'semi-presidential republic',
#  'parliamentary republic',
#  'mixed presidential-parliamentary system in free association with the US',
#  'presidential republic',
#  'parliamentary republic',
#  'federal presidential republic',
#  'federal republic in free association with the US',
#  'parliamentary republic',
#  'constitutional monarchy',
#  'semi-presidential republic',
#  'parliamentary republic',
#  'parliamentary democracy; self-governing overseas territory of the UK',
#  'parliamentary constitutional monarchy',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary republic',
#  'unorganized, unincorporated territory of the US; administered by the Fish and Wildlife Service, US Department of the Interior from the Caribbean Islands National Wildlife Refuge in Boqueron, Puerto Rico; in September 1996, the Coast Guard ceased operations and maintenance of the Navassa Island Light, a 46-meter-tall lighthouse on the southern side of the island; Haiti has claimed the island since the 19th century',
#  'federal parliamentary republic',
#  'parliamentary constitutional monarchy; part of the Kingdom of the Netherlands',
#  'parliamentary democracy (Territorial Congress); an overseas collectivity of France',
#  'parliamentary democracy\xa0under a constitutional monarchy; a Commonwealth realm',
#  'presidential republic',
#  "formerly, semi-presidential republicNote: on 26 July 2023, the National Council for the Safeguard of the Homeland, a military junta which took control of Niger's government, dissolved all government institutions, and rules by decree",
#  'federal presidential republic',
#  'parliamentary democracy',
#  'non-self-governing overseas territory of Australia; note - the Norfolk Island Regional Council, which began operations 1 July 2016, is responsible for planning and managing a variety of public services, including those funded by the Government of Australia',
#  'parliamentary republic',
#  'a commonwealth in political union with and under the sovereignty of the US; republican form of government with separate executive, legislative, and judicial branches',
#  'parliamentary constitutional monarchy',
#  'absolute monarchy',
#  'federal parliamentary republic',
#  'presidential republic in free association with the US',
#  'presidential republic',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'unknown',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary democracy',
#  'parliamentary republic',
#  'semi-presidential republic',
#  'unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches; note - reference Puerto Rican Federal Relations Act, 2 March 1917, as amended by Public Law 600, 3 July 1950',
#  'absolute monarchy',
#  'semi-presidential republic',
#  'semi-presidential federation',
#  'presidential republic',
#  'parliamentary democracy (Territorial Council); overseas collectivity of France',
#  'parliamentary democracy',
#  'federal parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'parliamentary democracy (Territorial Council); overseas collectivity of France',
#  'parliamentary democracy (Territorial Council); overseas collectivity of France',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'parliamentary republic',
#  'parliamentary republic',
#  'semi-presidential republic',
#  'absolute monarchy',
#  'presidential republic',
#  'parliamentary republic',
#  'presidential republic',
#  'presidential republic',
#  'parliamentary republic',
#  'parliamentary democracy under a constitutional monarchy',
#  'parliamentary republic',
#  'parliamentary republic',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'federal parliamentary republic',
#  'parliamentary republic',
#  'none (administered by the UK, claimed by Argentina)',
#  'presidential republic',
#  'parliamentary constitutional monarchy',
#  'unknown',
#  'presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'non-self-governing territory of Norway',
#  'parliamentary constitutional monarchy',
#  'federal republic (formally a confederation)',
#  'presidential republic; highly authoritarian regime',
#  'semi-presidential republic',
#  'presidential republic',
#  'presidential republic',
#  'constitutional monarchy',
#  'semi-presidential republic',
#  'presidential republic',
#  'parliamentary democracy under a constitutional monarchy',
#  'constitutional monarchy',
#  'parliamentary republic',
#  'parliamentary republic',
#  'presidential republic',
#  'presidential republic; authoritarian',
#  'parliamentary democracy',
#  'parliamentary democracy under a constitutional monarchy; a Commonwealth realm',
#  'presidential republic',
#  'semi-presidential republic',
#  'federation of monarchies',
#  'parliamentary constitutional monarchy; a Commonwealth realm',
#  'constitutional federal republic',
#  'presidential republic',
#  'presidential republic; highly authoritarian',
#  'parliamentary republic',
#  'federal presidential republic',
#  'communist party-led state',
#  'unincorporated organized territory of the US with local self-government; republican form of territorial government with separate executive, legislative, and judicial branches',
#  'none (territory of the US)',
#  'parliamentary democracy (Territorial Assembly); overseas collectivity of France',
#  'in transition',
#  'presidential republic',
#  'presidential republic']

# %%
# Convert the lists to DataFrames
data_date_ser = pd.Series(data_date)                                                                                                                             
data_date_df = data_date_ser.to_frame()

gov_type_ser = pd.Series(gov_type)                                                                                                                             
gov_type_df = gov_type_ser.to_frame()

prof_urls_ser = pd.Series(prof_urls)                                                                                                                             
prof_urls_df = prof_urls_ser.to_frame()

c_txt_ser = pd.Series(c_txt)                                                                                                                             
c_txt_df = c_txt_ser.to_frame()

# %%
data_date_df
# Out:
#                                        0
# 0    Page last updated: January 16, 2025
# 1    Page last updated: January 22, 2025
# 2    Page last updated: January 16, 2025
# 3    Page last updated: January 16, 2025
# 4    Page last updated: January 21, 2025
# ..                                   ...
# 245  Page last updated: January 16, 2025
# 246  Page last updated: January 18, 2025
# 247  Page last updated: January 18, 2025
# 248  Page last updated: January 21, 2025
# 249  Page last updated: January 18, 2025
#
# [250 rows x 1 columns]

# %%
# Merge the DataFrames and rename the columns
country_government_df = c_txt_df.merge(gov_type_df, left_index=True, right_index=True)

country_government_df = country_government_df.rename({'0_x': 'country', '0_y': 'government_type'}, axis=1)

country_government_df
# Out:
#                    country                                    government_type
# 0              Afghanistan  theocratic; the United States does not recogni...
# 1    Akrotiri and Dhekelia                none (overseas territory of the UK)
# 2                  Albania                             parliamentary republic
# 3                  Algeria                              presidential republic
# 4           American Samoa  unincorporated, unorganized Territory of the U...
# ..                     ...                                                ...
# 245            Wake Island                         none (territory of the US)
# 246      Wallis and Futuna  parliamentary democracy (Territorial Assembly)...
# 247                  Yemen                                      in transition
# 248                 Zambia                              presidential republic
# 249               Zimbabwe                              presidential republic
#
# [250 rows x 2 columns]

# %%
# Merge the DataFrames and rename the columns
country_government_df = country_government_df.merge(data_date_df, left_index=True, right_index=True)

country_government_df = country_government_df.rename({'country': 'country', 'government_type': 'government_type', '0': 'profile_data_date'}, axis=1)

country_government_df
# Out:
#                    country                                    government_type  \
# 0              Afghanistan  theocratic; the United States does not recogni...
# 1    Akrotiri and Dhekelia                none (overseas territory of the UK)
# 2                  Albania                             parliamentary republic
# 3                  Algeria                              presidential republic
# 4           American Samoa  unincorporated, unorganized Territory of the U...
# ..                     ...                                                ...
# 245            Wake Island                         none (territory of the US)
# 246      Wallis and Futuna  parliamentary democracy (Territorial Assembly)...
# 247                  Yemen                                      in transition
# 248                 Zambia                              presidential republic
# 249               Zimbabwe                              presidential republic
#
#                                        0
# 0    Page last updated: January 16, 2025
# 1    Page last updated: January 22, 2025
# 2    Page last updated: January 16, 2025
# 3    Page last updated: January 16, 2025
# 4    Page last updated: January 21, 2025
# ..                                   ...
# 245  Page last updated: January 16, 2025
# 246  Page last updated: January 18, 2025
# 247  Page last updated: January 18, 2025
# 248  Page last updated: January 21, 2025
# 249  Page last updated: January 18, 2025
#
# [250 rows x 3 columns]

# %%
country_government_df.to_csv('country_government_systems_2025.csv', index=False)

# %%
country_name_df = c_txt_df

# %%
# Merge the DataFrames and rename the columns
country_urls_df = country_name_df.merge(prof_urls_df, left_index=True, right_index=True)

country_urls_df  = country_urls_df .rename({'0_x': 'country', '0_y': 'profile_url'}, axis=1)

country_urls_df
# Out:
#                    country                                        profile_url
# 0              Afghanistan  https://www.cia.gov/the-world-factbook/countri...
# 1    Akrotiri and Dhekelia  https://www.cia.gov/the-world-factbook/countri...
# 2                  Albania  https://www.cia.gov/the-world-factbook/countri...
# 3                  Algeria  https://www.cia.gov/the-world-factbook/countri...
# 4           American Samoa  https://www.cia.gov/the-world-factbook/countri...
# ..                     ...                                                ...
# 245            Wake Island  https://www.cia.gov/the-world-factbook/countri...
# 246      Wallis and Futuna  https://www.cia.gov/the-world-factbook/countri...
# 247                  Yemen  https://www.cia.gov/the-world-factbook/countri...
# 248                 Zambia  https://www.cia.gov/the-world-factbook/countri...
# 249               Zimbabwe  https://www.cia.gov/the-world-factbook/countri...
#
# [250 rows x 2 columns]

# %%
country_urls_df.to_csv('country_government_urls_2025.csv', index=False)
